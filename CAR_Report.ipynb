# %% [markdown]
# <a href="https://colab.research.google.com/github/SSPYX/Colab/blob/main/CAR_Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy.core.multiarray import concatenate
import pandas as pd
import openpyxl
import numpy as np
import re
from openpyxl.styles import PatternFill, Border, Side, Alignment, Protection, Font

def adjust_merged_cells(sheet_name):
   #print("Inside function", sheet_name)
   merged_ranges = sheet_name.merged_cells.ranges
   print("Merged_range", merged_ranges)
   for merged_range in merged_ranges:
    min_row, min_col, max_row, max_col = merged_range.min_row, merged_range.min_col, merged_range.max_row, merged_range.max_col
    print("Merged Min Col", min_col, "Merged Max Col", max_col, "Merged Min row", min_row, "Merged Max row", max_row)
    hidden_columns = []
    for col in range(min_col, max_col + 1):
        if sheet_name.column_dimensions[openpyxl.utils.get_column_letter(col)].hidden:
                hidden_columns.append(col)
    #sheet_name.unmerge_cells(start_row=min_row, start_columns=min_col, end_row=max_row, end_col=max_col)
    for col in range(max_col, min_col - 1, -1):
        if col not in hidden_columns:
          for row in range(min_row, max_row + 1):
              cell_value = sheet_name.cell(row=row, column=col).value
              if cell_value:
                      sheet_name.cell(row=row, column=min_col).value = cell_value
                      break
    sheet_name.merge_cells(start_row=min_row, start_column=min_col, end_row=max_row, end_column=min_col + len(hidden_columns))

wb = openpyxl.load_workbook('/content/Copy of CAR Report DoT.xlsx', data_only=False, rich_text=True)
#sheet_names = wb.sheetnames
# Use the following SWITCH to define "scope" of the script. False = Do not apply, True = Apply
Font_Size_Switch = True
Row_Height_Switch = True
Border_Switch = False # False will not remove vertical borders
Column_Width_Switch = True
#print(wb.sheetnames)#
#for title in wb.sheetnames:
  #print("Start of", title)
ws = wb['1000']
CAR_sheet = wb['CAR']
#print(ws.title)
#  hidden_flg = ws.sheet_state
#  for row_index, row in enumerate(ws.iter_rows(min_row=0, max_row=1), start=1): # This is looping on row 1 in individual sheet
#    for cell in row:
      #print(cell.value)
#      if cell.value:
match_row_idx = 0
for row_indx_car, row_car in enumerate(CAR_sheet.iter_rows(min_row=1, max_row=1), start=1): # This loops over the first row in Target Sheet
    col_idx = 0
    for cell_c in row_car: #This loops over the columns values of row 1 in Target sheet
      if row_indx_car==1 and str(cell_c.value) == ws.title: # Check if the column belongs to the source sheet being parsed
        col_idx += 1
        #print(col_idx, cell_c.value) #This gives us the column index value of Target sheet
        for row_index, row in enumerate(ws.iter_rows(min_row=3), start=1): # This is looping over rows in source sheet
          for cell in row:  #This loop will provide the value of each column in source sheet
            if match_row_idx and cell.col_idx>2:
              print("Updating", {cell.value}, "in CAR Sheet on row index", {row_trgt_index})
              CAR_sheet.cell(row=match_row_idx, column=col_idx, value=cell.value)
              continue
            else:
              match_row_idx = 0
              for row_trgt_index, row_trgt in enumerate(CAR_sheet.iter_rows(min_row=4), start=1):
                if match_row_idx: #Exit from row loop when match found
                  break
                else:
                 for col_trgt in row_trgt:
                   if col_trgt.col_idx==3 and col_trgt.value==cell.value:
                      match_row_idx = row_trgt_index
                      print("Source value",cell.value, "Target Vlaue", col_trgt.value)
                      break #Exit from column loop when match found
wb.save('test.xlsx')
# Out:
# Source value H2_BS - Total Balance Sheet Target Vlaue H2_BS - Total Balance Sheet
# Updating {0} in CAR Sheet on row index {2}
# Updating {0.494002198} in CAR Sheet on row index {2}
# Updating {None} in CAR Sheet on row index {2}
# Updating {0} in CAR Sheet on row index {2}
# Updating {0} in CAR Sheet on row index {2}
# Updating {-0.017001152} in CAR Sheet on row index {2}
# Updating {0.477001046} in CAR Sheet on row index {2}
# Updating {0.497001991} in CAR Sheet on row index {2}
# Updating {0.002999793} in CAR Sheet on row index {2}
# Updating {'=+I3-J3'} in CAR Sheet on row index {2}
# Updating {None} in CAR Sheet on row index {2}
# Updating {'=SUM(C3:H3)-I3'} in CAR Sheet on row index {2}
# Updating {'=+L3-G3-H3+K3'} in CAR Sheet on row index {2}
# Source value H2_200000 - Total equity Target Vlaue H2_200000 - Total equity
# Updating {164978211042.45} in CAR Sheet on row index {3}
# Updating {11022.905997936} in CAR Sheet on row index {3}
# Updating {None} in CAR Sheet on row index {3}
# Updating {0} in CAR Sheet on row index {3}
# Updating {106430313.08} in CAR Sheet on row index {3}
# Updating {-0.002998888} in CAR Sheet on row index {3}
# Updating {165084652378.43298} in CAR Sheet on row index {3}
# Updating {164978222065.353} in CAR Sheet on row index {3}
# Updating {-0.002999872} in CAR Sheet on row index {3}
# Updating {'=+I4-J4'} in CAR Sheet on row index {3}
# Updating {None} in CAR Sheet on row index {3}
# Updating {'=SUM(C4:H4)-I4'} in CAR Sheet on row index {3}
# Updating {'=+L4-G4-H4+K4'} in CAR Sheet on row index {3}
# Source value H2_220000 - Accumulated funds Target Vlaue H2_220000 - Accumulated funds
# Updating {135974607839.72002} in CAR Sheet on row index {4}
# Updating {11022.905997991} in CAR Sheet on row index {4}
# Updating {None} in CAR Sheet on row index {4}
# Updating {0} in CAR Sheet on row index {4}
# Updating {106430313.08} in CAR Sheet on row index {4}
# Updating {-0.002998888} in CAR Sheet on row index {4}
# Updating {136081049175.703} in CAR Sheet on row index {4}
# Updating {135974618862.62299} in CAR Sheet on row index {4}
# Updating {-0.002999872} in CAR Sheet on row index {4}
# Updating {'=+I5-J5'} in CAR Sheet on row index {4}
# Updating {None} in CAR Sheet on row index {4}
# Updating {'=SUM(C5:H5)-I5'} in CAR Sheet on row index {4}
# Updating {'=+L5-G5-H5+K5'} in CAR Sheet on row index {4}
# Source value 220010 - Retained Surplus(Accum Losses) Target Vlaue 220010 - Retained Surplus(Accum Losses)
# Updating {108377348991.98001} in CAR Sheet on row index {5}
# Updating {-0.544000013} in CAR Sheet on row index {5}
# Updating {None} in CAR Sheet on row index {5}
# Updating {None} in CAR Sheet on row index {5}
# Updating {0} in CAR Sheet on row index {5}
# Updating {-0.002998984} in CAR Sheet on row index {5}
# Updating {108377348991.433} in CAR Sheet on row index {5}
# Updating {108377348991.433} in CAR Sheet on row index {5}
# Updating {-0.002999982} in CAR Sheet on row index {5}
# Updating {'=+I6-J6'} in CAR Sheet on row index {5}
# Updating {None} in CAR Sheet on row index {5}
# Updating {'=SUM(C6:H6)-I6'} in CAR Sheet on row index {5}
# Updating {'=+L6-G6-H6+K6'} in CAR Sheet on row index {5}
# Source value 220060 - Admin Restructure - OUT - PPE - PTE Target Vlaue 220060 - Admin Restructure - OUT - PPE - PTE
# Updating {0} in CAR Sheet on row index {7}
# Updating {3e-09} in CAR Sheet on row index {7}
# Updating {None} in CAR Sheet on row index {7}
# Updating {None} in CAR Sheet on row index {7}
# Updating {0} in CAR Sheet on row index {7}
# Updating {None} in CAR Sheet on row index {7}
# Updating {3e-09} in CAR Sheet on row index {7}
# Updating {3e-09} in CAR Sheet on row index {7}
# Updating {None} in CAR Sheet on row index {7}
# Updating {'=+I7-J7'} in CAR Sheet on row index {7}
# Updating {None} in CAR Sheet on row index {7}
# Updating {'=SUM(C7:H7)-I7'} in CAR Sheet on row index {7}
# Updating {'=+L7-G7-H7+K7'} in CAR Sheet on row index {7}
# Source value 221050 - Admin Restructure - IN - Receivables Government Target Vlaue 221050 - Admin Restructure - IN - Receivables Government
# Updating {0} in CAR Sheet on row index {10}
# Updating {None} in CAR Sheet on row index {10}
# Updating {None} in CAR Sheet on row index {10}
# Updating {None} in CAR Sheet on row index {10}
# Updating {None} in CAR Sheet on row index {10}
# Updating {None} in CAR Sheet on row index {10}
# Updating {0} in CAR Sheet on row index {10}
# Updating {1.2e-07} in CAR Sheet on row index {10}
# Updating {1.2e-07} in CAR Sheet on row index {10}
# Updating {'=+I8-J8'} in CAR Sheet on row index {10}
# Updating {None} in CAR Sheet on row index {10}
# Updating {'=SUM(C8:H8)-I8'} in CAR Sheet on row index {10}
# Updating {'=+L8-G8-H8+K8'} in CAR Sheet on row index {10}
# Source value 221110 - Admin Restructure - Borrowings Target Vlaue 221110 - Admin Restructure - Borrowings
# Updating {None} in CAR Sheet on row index {13}
# Updating {None} in CAR Sheet on row index {13}
# Updating {None} in CAR Sheet on row index {13}
# Updating {None} in CAR Sheet on row index {13}
# Updating {None} in CAR Sheet on row index {13}
# Updating {None} in CAR Sheet on row index {13}
# Updating {None} in CAR Sheet on row index {13}
# Updating {-2e-08} in CAR Sheet on row index {13}
# Updating {-2e-08} in CAR Sheet on row index {13}
# Updating {'=+I9-J9'} in CAR Sheet on row index {13}
# Updating {None} in CAR Sheet on row index {13}
# Updating {'=SUM(C9:H9)-I9'} in CAR Sheet on row index {13}
# Updating {'=+L9-G9-H9+K9'} in CAR Sheet on row index {13}
# Source value 220010_C - Calculated Retained Earnings Target Vlaue 220010_C - Calculated Retained Earnings
# Updating {6253014388.74} in CAR Sheet on row index {15}
# Updating {11023.45} in CAR Sheet on row index {15}
# Updating {None} in CAR Sheet on row index {15}
# Updating {None} in CAR Sheet on row index {15}
# Updating {-7784571210.599999} in CAR Sheet on row index {15}
# Updating {None} in CAR Sheet on row index {15}
# Updating {-1531545798.41} in CAR Sheet on row index {15}
# Updating {6253025412.19} in CAR Sheet on row index {15}
# Updating {0} in CAR Sheet on row index {15}
# Updating {'=+I10-J10'} in CAR Sheet on row index {15}
# Updating {None} in CAR Sheet on row index {15}
# Updating {'=SUM(C10:H10)-I10'} in CAR Sheet on row index {15}
# Updating {'=+L10-G10-H10+K10'} in CAR Sheet on row index {15}
# Source value 220015 - Retained Surplus/(Accum Losses) Manual Posting Target Vlaue 220015 - Retained Surplus/(Accum Losses) Manual Posting
# Updating {21341371918.350002} in CAR Sheet on row index {19}
# Updating {-2e-06} in CAR Sheet on row index {19}
# Updating {None} in CAR Sheet on row index {19}
# Updating {None} in CAR Sheet on row index {19}
# Updating {-166029.07} in CAR Sheet on row index {19}
# Updating {None} in CAR Sheet on row index {19}
# Updating {21341205889.28} in CAR Sheet on row index {19}
# Updating {21341371918.35} in CAR Sheet on row index {19}
# Updating {1e-09} in CAR Sheet on row index {19}
# Updating {'=+I11-J11'} in CAR Sheet on row index {19}
# Updating {None} in CAR Sheet on row index {19}
# Updating {'=SUM(C11:H11)-I11'} in CAR Sheet on row index {19}
# Updating {'=+L11-G11-H11+K11'} in CAR Sheet on row index {19}
# Source value 220045 - Accumulated funds - transfers from reserves Target Vlaue 220045 - Accumulated funds - transfers from reserves
# Updating {0} in CAR Sheet on row index {20}
# Updating {1e-09} in CAR Sheet on row index {20}
# Updating {None} in CAR Sheet on row index {20}
# Updating {None} in CAR Sheet on row index {20}
# Updating {None} in CAR Sheet on row index {20}
# Updating {-3e-09} in CAR Sheet on row index {20}
# Updating {-2e-09} in CAR Sheet on row index {20}
# Updating {1e-09} in CAR Sheet on row index {20}
# Updating {None} in CAR Sheet on row index {20}
# Updating {'=+I12-J12'} in CAR Sheet on row index {20}
# Updating {None} in CAR Sheet on row index {20}
# Updating {'=SUM(C12:H12)-I12'} in CAR Sheet on row index {20}
# Updating {'=+L12-G12-H12+K12'} in CAR Sheet on row index {20}
# Source value 220065 - Admin Restructure - OUT - PPE - GG Target Vlaue 220065 - Admin Restructure - OUT - PPE - GG
# Updating {-23136.35} in CAR Sheet on row index {21}
# Updating {None} in CAR Sheet on row index {21}
# Updating {None} in CAR Sheet on row index {21}
# Updating {None} in CAR Sheet on row index {21}
# Updating {None} in CAR Sheet on row index {21}
# Updating {None} in CAR Sheet on row index {21}
# Updating {-23136.35} in CAR Sheet on row index {21}
# Updating {-23136.35} in CAR Sheet on row index {21}
# Updating {None} in CAR Sheet on row index {21}
# Updating {'=+I13-J13'} in CAR Sheet on row index {21}
# Updating {None} in CAR Sheet on row index {21}
# Updating {'=SUM(C13:H13)-I13'} in CAR Sheet on row index {21}
# Updating {'=+L13-G13-H13+K13'} in CAR Sheet on row index {21}
# Source value 221095 - Admin Restructure - IN - Other Provisions Target Vlaue 221095 - Admin Restructure - IN - Other Provisions
# Updating {None} in CAR Sheet on row index {22}
# Updating {None} in CAR Sheet on row index {22}
# Updating {None} in CAR Sheet on row index {22}
# Updating {None} in CAR Sheet on row index {22}
# Updating {None} in CAR Sheet on row index {22}
# Updating {None} in CAR Sheet on row index {22}
# Updating {None} in CAR Sheet on row index {22}
# Updating {9e-09} in CAR Sheet on row index {22}
# Updating {9e-09} in CAR Sheet on row index {22}
# Updating {'=+I14-J14'} in CAR Sheet on row index {22}
# Updating {None} in CAR Sheet on row index {22}
# Updating {'=SUM(C14:H14)-I14'} in CAR Sheet on row index {22}
# Updating {'=+L14-G14-H14+K14'} in CAR Sheet on row index {22}
# Source value 999999_C - Calculated Intercompany Balancing Plug Target Vlaue 999999_C - Calculated Intercompany Balancing Plug
# Updating {None} in CAR Sheet on row index {23}
# Updating {None} in CAR Sheet on row index {23}
# Updating {None} in CAR Sheet on row index {23}
# Updating {None} in CAR Sheet on row index {23}
# Updating {7891167552.75} in CAR Sheet on row index {23}
# Updating {None} in CAR Sheet on row index {23}
# Updating {7891167552.75} in CAR Sheet on row index {23}
# Updating {None} in CAR Sheet on row index {23}
# Updating {None} in CAR Sheet on row index {23}
# Updating {'=+I15-J15'} in CAR Sheet on row index {23}
# Updating {None} in CAR Sheet on row index {23}
# Updating {'=SUM(C15:H15)-I15'} in CAR Sheet on row index {23}
# Updating {'=+L15-G15-H15+K15'} in CAR Sheet on row index {23}
# Source value 221115 - Admin Restructure - IN - Other liabilities Target Vlaue 221115 - Admin Restructure - IN - Other liabilities
# Updating {None} in CAR Sheet on row index {25}
# Updating {None} in CAR Sheet on row index {25}
# Updating {None} in CAR Sheet on row index {25}
# Updating {None} in CAR Sheet on row index {25}
# Updating {None} in CAR Sheet on row index {25}
# Updating {None} in CAR Sheet on row index {25}
# Updating {None} in CAR Sheet on row index {25}
# Updating {1e-08} in CAR Sheet on row index {25}
# Updating {1e-08} in CAR Sheet on row index {25}
# Updating {'=+I16-J16'} in CAR Sheet on row index {25}
# Updating {None} in CAR Sheet on row index {25}
# Updating {'=SUM(C16:H16)-I16'} in CAR Sheet on row index {25}
# Updating {'=+L16-G16-H16+K16'} in CAR Sheet on row index {25}
# Source value 221040 - Admin Restructure-IN-Other assets Target Vlaue 221040 - Admin Restructure-IN-Other assets
# Updating {None} in CAR Sheet on row index {26}
# Updating {None} in CAR Sheet on row index {26}
# Updating {None} in CAR Sheet on row index {26}
# Updating {None} in CAR Sheet on row index {26}
# Updating {None} in CAR Sheet on row index {26}
# Updating {None} in CAR Sheet on row index {26}
# Updating {None} in CAR Sheet on row index {26}
# Updating {-1e-08} in CAR Sheet on row index {26}
# Updating {-1e-08} in CAR Sheet on row index {26}
# Updating {'=+I17-J17'} in CAR Sheet on row index {26}
# Updating {None} in CAR Sheet on row index {26}
# Updating {'=SUM(C17:H17)-I17'} in CAR Sheet on row index {26}
# Updating {'=+L17-G17-H17+K17'} in CAR Sheet on row index {26}
# Source value 221035 - Admin Restructure - IN - PPE  - GG Target Vlaue 221035 - Admin Restructure - IN - PPE  - GG
# Updating {2895677} in CAR Sheet on row index {28}
# Updating {0} in CAR Sheet on row index {28}
# Updating {None} in CAR Sheet on row index {28}
# Updating {0} in CAR Sheet on row index {28}
# Updating {0} in CAR Sheet on row index {28}
# Updating {None} in CAR Sheet on row index {28}
# Updating {2895677} in CAR Sheet on row index {28}
# Updating {2895677} in CAR Sheet on row index {28}
# Updating {None} in CAR Sheet on row index {28}
# Updating {'=+I18-J18'} in CAR Sheet on row index {28}
# Updating {None} in CAR Sheet on row index {28}
# Updating {'=SUM(C18:H18)-I18'} in CAR Sheet on row index {28}
# Updating {'=+L18-G18-H18+K18'} in CAR Sheet on row index {28}
# Source value 220018 - Accumulated funds- changes in accounting policy Target Vlaue 220018 - Accumulated funds- changes in accounting policy
# Updating {0} in CAR Sheet on row index {29}
# Updating {None} in CAR Sheet on row index {29}
# Updating {None} in CAR Sheet on row index {29}
# Updating {None} in CAR Sheet on row index {29}
# Updating {None} in CAR Sheet on row index {29}
# Updating {9.9e-08} in CAR Sheet on row index {29}
# Updating {9.9e-08} in CAR Sheet on row index {29}
# Updating {0} in CAR Sheet on row index {29}
# Updating {None} in CAR Sheet on row index {29}
# Updating {'=+I19-J19'} in CAR Sheet on row index {29}
# Updating {None} in CAR Sheet on row index {29}
# Updating {'=SUM(C19:H19)-I19'} in CAR Sheet on row index {29}
# Updating {'=+L19-G19-H19+K19'} in CAR Sheet on row index {29}
# Source value H2_240000 - Reserves Target Vlaue H2_240000 - Reserves
# Updating {29003603202.73} in CAR Sheet on row index {30}
# Updating {-5.5e-08} in CAR Sheet on row index {30}
# Updating {None} in CAR Sheet on row index {30}
# Updating {0} in CAR Sheet on row index {30}
# Updating {None} in CAR Sheet on row index {30}
# Updating {None} in CAR Sheet on row index {30}
# Updating {29003603202.73} in CAR Sheet on row index {30}
# Updating {29003603202.73} in CAR Sheet on row index {30}
# Updating {None} in CAR Sheet on row index {30}
# Updating {'=+I20-J20'} in CAR Sheet on row index {30}
# Updating {None} in CAR Sheet on row index {30}
# Updating {'=SUM(C20:H20)-I20'} in CAR Sheet on row index {30}
# Updating {'=+L20-G20-H20+K20'} in CAR Sheet on row index {30}
# Source value H2_210000 - Asset revaluation surplus Target Vlaue H2_210000 - Asset revaluation surplus
# Updating {29003603202.73} in CAR Sheet on row index {31}
# Updating {-5.5e-08} in CAR Sheet on row index {31}
# Updating {None} in CAR Sheet on row index {31}
# Updating {0} in CAR Sheet on row index {31}
# Updating {None} in CAR Sheet on row index {31}
# Updating {None} in CAR Sheet on row index {31}
# Updating {29003603202.73} in CAR Sheet on row index {31}
# Updating {29003603202.73} in CAR Sheet on row index {31}
# Updating {None} in CAR Sheet on row index {31}
# Updating {'=+I21-J21'} in CAR Sheet on row index {31}
# Updating {None} in CAR Sheet on row index {31}
# Updating {'=SUM(C21:H21)-I21'} in CAR Sheet on row index {31}
# Updating {'=+L21-G21-H21+K21'} in CAR Sheet on row index {31}
# Source value 211020 - Asset Reval Reserve - Land Target Vlaue 211020 - Asset Reval Reserve - Land
# Updating {239205749.46} in CAR Sheet on row index {32}
# Updating {None} in CAR Sheet on row index {32}
# Updating {None} in CAR Sheet on row index {32}
# Updating {0} in CAR Sheet on row index {32}
# Updating {None} in CAR Sheet on row index {32}
# Updating {None} in CAR Sheet on row index {32}
# Updating {239205749.45999998} in CAR Sheet on row index {32}
# Updating {239205749.45999998} in CAR Sheet on row index {32}
# Updating {None} in CAR Sheet on row index {32}
# Updating {'=+I22-J22'} in CAR Sheet on row index {32}
# Updating {None} in CAR Sheet on row index {32}
# Updating {'=SUM(C22:H22)-I22'} in CAR Sheet on row index {32}
# Updating {'=+L22-G22-H22+K22'} in CAR Sheet on row index {32}
# Source value 211040 - Asset Reval Reserve - Plant & Equipment Target Vlaue 211040 - Asset Reval Reserve - Plant & Equipment
# Updating {1908862.52} in CAR Sheet on row index {33}
# Updating {None} in CAR Sheet on row index {33}
# Updating {None} in CAR Sheet on row index {33}
# Updating {None} in CAR Sheet on row index {33}
# Updating {None} in CAR Sheet on row index {33}
# Updating {None} in CAR Sheet on row index {33}
# Updating {1908862.52} in CAR Sheet on row index {33}
# Updating {1908862.52} in CAR Sheet on row index {33}
# Updating {None} in CAR Sheet on row index {33}
# Updating {'=+I23-J23'} in CAR Sheet on row index {33}
# Updating {None} in CAR Sheet on row index {33}
# Updating {'=SUM(C23:H23)-I23'} in CAR Sheet on row index {33}
# Updating {'=+L23-G23-H23+K23'} in CAR Sheet on row index {33}
# Source value 211060 - Asset Reval Reserve - Road Infrastructure Target Vlaue 211060 - Asset Reval Reserve - Road Infrastructure
# Updating {15823424823.86} in CAR Sheet on row index {34}
# Updating {-4e-08} in CAR Sheet on row index {34}
# Updating {None} in CAR Sheet on row index {34}
# Updating {None} in CAR Sheet on row index {34}
# Updating {None} in CAR Sheet on row index {34}
# Updating {None} in CAR Sheet on row index {34}
# Updating {15823424823.86} in CAR Sheet on row index {34}
# Updating {15823424823.86} in CAR Sheet on row index {34}
# Updating {None} in CAR Sheet on row index {34}
# Updating {'=+I24-J24'} in CAR Sheet on row index {34}
# Updating {None} in CAR Sheet on row index {34}
# Updating {'=SUM(C24:H24)-I24'} in CAR Sheet on row index {34}
# Updating {'=+L24-G24-H24+K24'} in CAR Sheet on row index {34}
# Source value 211070 - Asset Reval Reserve - Maritime Infrastructure Target Vlaue 211070 - Asset Reval Reserve - Maritime Infrastructure
# Updating {539385068.79} in CAR Sheet on row index {35}
# Updating {None} in CAR Sheet on row index {35}
# Updating {None} in CAR Sheet on row index {35}
# Updating {None} in CAR Sheet on row index {35}
# Updating {None} in CAR Sheet on row index {35}
# Updating {None} in CAR Sheet on row index {35}
# Updating {539385068.79} in CAR Sheet on row index {35}
# Updating {539385068.79} in CAR Sheet on row index {35}
# Updating {None} in CAR Sheet on row index {35}
# Updating {'=+I25-J25'} in CAR Sheet on row index {35}
# Updating {None} in CAR Sheet on row index {35}
# Updating {'=SUM(C25:H25)-I25'} in CAR Sheet on row index {35}
# Updating {'=+L25-G25-H25+K25'} in CAR Sheet on row index {35}
# Source value 211090 - Asset Reval Reserve - Rolling Stock Target Vlaue 211090 - Asset Reval Reserve - Rolling Stock
# Updating {14546601.51} in CAR Sheet on row index {36}
# Updating {None} in CAR Sheet on row index {36}
# Updating {None} in CAR Sheet on row index {36}
# Updating {None} in CAR Sheet on row index {36}
# Updating {None} in CAR Sheet on row index {36}
# Updating {None} in CAR Sheet on row index {36}
# Updating {14546601.51} in CAR Sheet on row index {36}
# Updating {14546601.51} in CAR Sheet on row index {36}
# Updating {None} in CAR Sheet on row index {36}
# Updating {'=+I26-J26'} in CAR Sheet on row index {36}
# Updating {None} in CAR Sheet on row index {36}
# Updating {'=SUM(C26:H26)-I26'} in CAR Sheet on row index {36}
# Updating {'=+L26-G26-H26+K26'} in CAR Sheet on row index {36}
# Source value 211100 - Asset Reval Reserve - Ferries Target Vlaue 211100 - Asset Reval Reserve - Ferries
# Updating {9492049.2} in CAR Sheet on row index {37}
# Updating {None} in CAR Sheet on row index {37}
# Updating {None} in CAR Sheet on row index {37}
# Updating {None} in CAR Sheet on row index {37}
# Updating {None} in CAR Sheet on row index {37}
# Updating {None} in CAR Sheet on row index {37}
# Updating {9492049.200000001} in CAR Sheet on row index {37}
# Updating {9492049.200000001} in CAR Sheet on row index {37}
# Updating {None} in CAR Sheet on row index {37}
# Updating {'=+I27-J27'} in CAR Sheet on row index {37}
# Updating {None} in CAR Sheet on row index {37}
# Updating {'=SUM(C27:H27)-I27'} in CAR Sheet on row index {37}
# Updating {'=+L27-G27-H27+K27'} in CAR Sheet on row index {37}
# Source value 211110 - Asset Reval Reserve - Buses Target Vlaue 211110 - Asset Reval Reserve - Buses
# Updating {10834745.83} in CAR Sheet on row index {38}
# Updating {None} in CAR Sheet on row index {38}
# Updating {None} in CAR Sheet on row index {38}
# Updating {None} in CAR Sheet on row index {38}
# Updating {None} in CAR Sheet on row index {38}
# Updating {None} in CAR Sheet on row index {38}
# Updating {10834745.83} in CAR Sheet on row index {38}
# Updating {10834745.83} in CAR Sheet on row index {38}
# Updating {None} in CAR Sheet on row index {38}
# Updating {'=+I28-J28'} in CAR Sheet on row index {38}
# Updating {None} in CAR Sheet on row index {38}
# Updating {'=SUM(C28:H28)-I28'} in CAR Sheet on row index {38}
# Updating {'=+L28-G28-H28+K28'} in CAR Sheet on row index {38}
# Source value 211030 - Asset Reval Reserve - Buildings Target Vlaue 211030 - Asset Reval Reserve - Buildings
# Updating {15679320.69} in CAR Sheet on row index {39}
# Updating {None} in CAR Sheet on row index {39}
# Updating {None} in CAR Sheet on row index {39}
# Updating {None} in CAR Sheet on row index {39}
# Updating {None} in CAR Sheet on row index {39}
# Updating {None} in CAR Sheet on row index {39}
# Updating {15679320.69} in CAR Sheet on row index {39}
# Updating {15679320.69} in CAR Sheet on row index {39}
# Updating {None} in CAR Sheet on row index {39}
# Updating {'=+I29-J29'} in CAR Sheet on row index {39}
# Updating {None} in CAR Sheet on row index {39}
# Updating {'=SUM(C29:H29)-I29'} in CAR Sheet on row index {39}
# Updating {'=+L29-G29-H29+K29'} in CAR Sheet on row index {39}
# Source value 211050 - Asset Reval Reserve - Rail Infrastructure Target Vlaue 211050 - Asset Reval Reserve - Rail Infrastructure
# Updating {203531057.03} in CAR Sheet on row index {40}
# Updating {None} in CAR Sheet on row index {40}
# Updating {None} in CAR Sheet on row index {40}
# Updating {None} in CAR Sheet on row index {40}
# Updating {None} in CAR Sheet on row index {40}
# Updating {None} in CAR Sheet on row index {40}
# Updating {203531057.02999997} in CAR Sheet on row index {40}
# Updating {203531057.02999997} in CAR Sheet on row index {40}
# Updating {None} in CAR Sheet on row index {40}
# Updating {'=+I30-J30'} in CAR Sheet on row index {40}
# Updating {None} in CAR Sheet on row index {40}
# Updating {'=SUM(C30:H30)-I30'} in CAR Sheet on row index {40}
# Updating {'=+L30-G30-H30+K30'} in CAR Sheet on row index {40}
# Source value 211021 - Asset Reval Reserve - Admin Land Target Vlaue 211021 - Asset Reval Reserve - Admin Land
# Updating {0} in CAR Sheet on row index {41}
# Updating {1.1e-08} in CAR Sheet on row index {41}
# Updating {None} in CAR Sheet on row index {41}
# Updating {None} in CAR Sheet on row index {41}
# Updating {None} in CAR Sheet on row index {41}
# Updating {None} in CAR Sheet on row index {41}
# Updating {1.1e-08} in CAR Sheet on row index {41}
# Updating {1.1e-08} in CAR Sheet on row index {41}
# Updating {None} in CAR Sheet on row index {41}
# Updating {'=+I31-J31'} in CAR Sheet on row index {41}
# Updating {None} in CAR Sheet on row index {41}
# Updating {'=SUM(C31:H31)-I31'} in CAR Sheet on row index {41}
# Updating {'=+L31-G31-H31+K31'} in CAR Sheet on row index {41}
# Source value 211023 - Asset Reval Reserve - Land Under Roads Target Vlaue 211023 - Asset Reval Reserve - Land Under Roads
# Updating {550028255.98} in CAR Sheet on row index {42}
# Updating {-6e-09} in CAR Sheet on row index {42}
# Updating {None} in CAR Sheet on row index {42}
# Updating {None} in CAR Sheet on row index {42}
# Updating {None} in CAR Sheet on row index {42}
# Updating {None} in CAR Sheet on row index {42}
# Updating {550028255.98} in CAR Sheet on row index {42}
# Updating {550028255.98} in CAR Sheet on row index {42}
# Updating {None} in CAR Sheet on row index {42}
# Updating {'=+I32-J32'} in CAR Sheet on row index {42}
# Updating {None} in CAR Sheet on row index {42}
# Updating {'=SUM(C32:H32)-I32'} in CAR Sheet on row index {42}
# Updating {'=+L32-G32-H32+K32'} in CAR Sheet on row index {42}
# Source value 211063 - Asset Reval Reserve - Traffic Control Infrastr Target Vlaue 211063 - Asset Reval Reserve - Traffic Control Infrastr
# Updating {345104028.71999997} in CAR Sheet on row index {43}
# Updating {None} in CAR Sheet on row index {43}
# Updating {None} in CAR Sheet on row index {43}
# Updating {None} in CAR Sheet on row index {43}
# Updating {None} in CAR Sheet on row index {43}
# Updating {None} in CAR Sheet on row index {43}
# Updating {345104028.72} in CAR Sheet on row index {43}
# Updating {345104028.72} in CAR Sheet on row index {43}
# Updating {None} in CAR Sheet on row index {43}
# Updating {'=+I33-J33'} in CAR Sheet on row index {43}
# Updating {None} in CAR Sheet on row index {43}
# Updating {'=SUM(C33:H33)-I33'} in CAR Sheet on row index {43}
# Updating {'=+L33-G33-H33+K33'} in CAR Sheet on row index {43}
# Source value 211064 - Asset Reval Reserve - Traffic Signal Infrastr Target Vlaue 211064 - Asset Reval Reserve - Traffic Signal Infrastr
# Updating {147865371.35999998} in CAR Sheet on row index {44}
# Updating {None} in CAR Sheet on row index {44}
# Updating {None} in CAR Sheet on row index {44}
# Updating {None} in CAR Sheet on row index {44}
# Updating {None} in CAR Sheet on row index {44}
# Updating {None} in CAR Sheet on row index {44}
# Updating {147865371.35999998} in CAR Sheet on row index {44}
# Updating {147865371.35999998} in CAR Sheet on row index {44}
# Updating {None} in CAR Sheet on row index {44}
# Updating {'=+I34-J34'} in CAR Sheet on row index {44}
# Updating {None} in CAR Sheet on row index {44}
# Updating {'=SUM(C34:H34)-I34'} in CAR Sheet on row index {44}
# Updating {'=+L34-G34-H34+K34'} in CAR Sheet on row index {44}
# Source value 211066 - Asset Reval Reserve - Bridges Target Vlaue 211066 - Asset Reval Reserve - Bridges
# Updating {6367285288.7} in CAR Sheet on row index {46}
# Updating {-2e-08} in CAR Sheet on row index {46}
# Updating {None} in CAR Sheet on row index {46}
# Updating {None} in CAR Sheet on row index {46}
# Updating {None} in CAR Sheet on row index {46}
# Updating {None} in CAR Sheet on row index {46}
# Updating {6367285288.7} in CAR Sheet on row index {46}
# Updating {6367285288.7} in CAR Sheet on row index {46}
# Updating {None} in CAR Sheet on row index {46}
# Updating {'=+I35-J35'} in CAR Sheet on row index {46}
# Updating {None} in CAR Sheet on row index {46}
# Updating {'=SUM(C35:H35)-I35'} in CAR Sheet on row index {46}
# Updating {'=+L35-G35-H35+K35'} in CAR Sheet on row index {46}
# Source value 211121 - Asset Reval Reserve - LAFFRW Target Vlaue 211121 - Asset Reval Reserve - LAFFRW
# Updating {-62809455.120000005} in CAR Sheet on row index {47}
# Updating {0} in CAR Sheet on row index {47}
# Updating {None} in CAR Sheet on row index {47}
# Updating {None} in CAR Sheet on row index {47}
# Updating {None} in CAR Sheet on row index {47}
# Updating {None} in CAR Sheet on row index {47}
# Updating {-62809455.12} in CAR Sheet on row index {47}
# Updating {-62809455.12} in CAR Sheet on row index {47}
# Updating {None} in CAR Sheet on row index {47}
# Updating {'=+I36-J36'} in CAR Sheet on row index {47}
# Updating {None} in CAR Sheet on row index {47}
# Updating {'=SUM(C36:H36)-I36'} in CAR Sheet on row index {47}
# Updating {'=+L36-G36-H36+K36'} in CAR Sheet on row index {47}
# Source value 211170 - Asset reval reserve - service concession infrast Target Vlaue 211170 - Asset reval reserve - service concession infrast
# Updating {993151355.3100001} in CAR Sheet on row index {48}
# Updating {None} in CAR Sheet on row index {48}
# Updating {None} in CAR Sheet on row index {48}
# Updating {None} in CAR Sheet on row index {48}
# Updating {None} in CAR Sheet on row index {48}
# Updating {None} in CAR Sheet on row index {48}
# Updating {993151355.3100001} in CAR Sheet on row index {48}
# Updating {993151355.3100001} in CAR Sheet on row index {48}
# Updating {None} in CAR Sheet on row index {48}
# Updating {'=+I37-J37'} in CAR Sheet on row index {48}
# Updating {None} in CAR Sheet on row index {48}
# Updating {'=SUM(C37:H37)-I37'} in CAR Sheet on row index {48}
# Updating {'=+L37-G37-H37+K37'} in CAR Sheet on row index {48}
# Source value 211180 - Asset reval resrve-service concession infra Rail Target Vlaue 211180 - Asset reval resrve-service concession infra Rail
# Updating {195369999.5} in CAR Sheet on row index {49}
# Updating {None} in CAR Sheet on row index {49}
# Updating {None} in CAR Sheet on row index {49}
# Updating {None} in CAR Sheet on row index {49}
# Updating {None} in CAR Sheet on row index {49}
# Updating {None} in CAR Sheet on row index {49}
# Updating {195369999.5} in CAR Sheet on row index {49}
# Updating {195369999.5} in CAR Sheet on row index {49}
# Updating {None} in CAR Sheet on row index {49}
# Updating {'=+I38-J38'} in CAR Sheet on row index {49}
# Updating {None} in CAR Sheet on row index {49}
# Updating {'=SUM(C38:H38)-I38'} in CAR Sheet on row index {49}
# Updating {'=+L38-G38-H38+K38'} in CAR Sheet on row index {49}
# Source value 211185 - Asset reval reserve - service concession Land Target Vlaue 211185 - Asset reval reserve - service concession Land
# Updating {-40637658} in CAR Sheet on row index {50}
# Updating {None} in CAR Sheet on row index {50}
# Updating {None} in CAR Sheet on row index {50}
# Updating {None} in CAR Sheet on row index {50}
# Updating {None} in CAR Sheet on row index {50}
# Updating {None} in CAR Sheet on row index {50}
# Updating {-40637658} in CAR Sheet on row index {50}
# Updating {-40637658} in CAR Sheet on row index {50}
# Updating {None} in CAR Sheet on row index {50}
# Updating {'=+I39-J39'} in CAR Sheet on row index {50}
# Updating {None} in CAR Sheet on row index {50}
# Updating {'=SUM(C39:H39)-I39'} in CAR Sheet on row index {50}
# Updating {'=+L39-G39-H39+K39'} in CAR Sheet on row index {50}
# Source value 211190 - Asset reval reserve - service conce Rolling Stock Target Vlaue 211190 - Asset reval reserve - service conce Rolling Stock
# Updating {22939916.979999997} in CAR Sheet on row index {51}
# Updating {None} in CAR Sheet on row index {51}
# Updating {None} in CAR Sheet on row index {51}
# Updating {None} in CAR Sheet on row index {51}
# Updating {None} in CAR Sheet on row index {51}
# Updating {None} in CAR Sheet on row index {51}
# Updating {22939916.98} in CAR Sheet on row index {51}
# Updating {22939916.98} in CAR Sheet on row index {51}
# Updating {None} in CAR Sheet on row index {51}
# Updating {'=+I40-J40'} in CAR Sheet on row index {51}
# Updating {None} in CAR Sheet on row index {51}
# Updating {'=SUM(C40:H40)-I40'} in CAR Sheet on row index {51}
# Updating {'=+L40-G40-H40+K40'} in CAR Sheet on row index {51}
# Source value 211024 - Asset Revaluation Reserve - Land under Track Target Vlaue 211024 - Asset Revaluation Reserve - Land under Track
# Updating {3976683.8} in CAR Sheet on row index {52}
# Updating {None} in CAR Sheet on row index {52}
# Updating {None} in CAR Sheet on row index {52}
# Updating {None} in CAR Sheet on row index {52}
# Updating {None} in CAR Sheet on row index {52}
# Updating {None} in CAR Sheet on row index {52}
# Updating {3976683.8000000003} in CAR Sheet on row index {52}
# Updating {3976683.8000000003} in CAR Sheet on row index {52}
# Updating {None} in CAR Sheet on row index {52}
# Updating {'=+I41-J41'} in CAR Sheet on row index {52}
# Updating {None} in CAR Sheet on row index {52}
# Updating {'=SUM(C41:H41)-I41'} in CAR Sheet on row index {52}
# Updating {'=+L41-G41-H41+K41'} in CAR Sheet on row index {52}
# Source value 211175 - Asset reval reserve-service concesion infr Bridges Target Vlaue 211175 - Asset reval reserve-service concesion infr Bridges
# Updating {2782024715.15} in CAR Sheet on row index {53}
# Updating {None} in CAR Sheet on row index {53}
# Updating {None} in CAR Sheet on row index {53}
# Updating {None} in CAR Sheet on row index {53}
# Updating {None} in CAR Sheet on row index {53}
# Updating {None} in CAR Sheet on row index {53}
# Updating {2782024715.15} in CAR Sheet on row index {53}
# Updating {2782024715.15} in CAR Sheet on row index {53}
# Updating {None} in CAR Sheet on row index {53}
# Updating {'=+I42-J42'} in CAR Sheet on row index {53}
# Updating {None} in CAR Sheet on row index {53}
# Updating {'=SUM(C42:H42)-I42'} in CAR Sheet on row index {53}
# Updating {'=+L42-G42-H42+K42'} in CAR Sheet on row index {53}
# Source value 211195 - Asset reval resve-serv conces infr Traffic Control Target Vlaue 211195 - Asset reval resve-serv conces infr Traffic Control
# Updating {299234090.71999997} in CAR Sheet on row index {54}
# Updating {None} in CAR Sheet on row index {54}
# Updating {None} in CAR Sheet on row index {54}
# Updating {None} in CAR Sheet on row index {54}
# Updating {None} in CAR Sheet on row index {54}
# Updating {None} in CAR Sheet on row index {54}
# Updating {299234090.72} in CAR Sheet on row index {54}
# Updating {299234090.72} in CAR Sheet on row index {54}
# Updating {None} in CAR Sheet on row index {54}
# Updating {'=+I43-J43'} in CAR Sheet on row index {54}
# Updating {None} in CAR Sheet on row index {54}
# Updating {'=SUM(C43:H43)-I43'} in CAR Sheet on row index {54}
# Updating {'=+L43-G43-H43+K43'} in CAR Sheet on row index {54}
# Source value 211032 - Asset reval reserve-service conces building &Impro Target Vlaue 211032 - Asset reval reserve-service conces building &Impro
# Updating {977944.85} in CAR Sheet on row index {55}
# Updating {None} in CAR Sheet on row index {55}
# Updating {None} in CAR Sheet on row index {55}
# Updating {None} in CAR Sheet on row index {55}
# Updating {None} in CAR Sheet on row index {55}
# Updating {None} in CAR Sheet on row index {55}
# Updating {977944.85} in CAR Sheet on row index {55}
# Updating {977944.85} in CAR Sheet on row index {55}
# Updating {None} in CAR Sheet on row index {55}
# Updating {'=+I44-J44'} in CAR Sheet on row index {55}
# Updating {None} in CAR Sheet on row index {55}
# Updating {'=SUM(C44:H44)-I44'} in CAR Sheet on row index {55}
# Updating {'=+L44-G44-H44+K44'} in CAR Sheet on row index {55}
# Source value 211033 - Asset reval res-serv conc building toll road Target Vlaue 211033 - Asset reval res-serv conc building toll road
# Updating {13599436.13} in CAR Sheet on row index {56}
# Updating {None} in CAR Sheet on row index {56}
# Updating {None} in CAR Sheet on row index {56}
# Updating {None} in CAR Sheet on row index {56}
# Updating {None} in CAR Sheet on row index {56}
# Updating {None} in CAR Sheet on row index {56}
# Updating {13599436.129999999} in CAR Sheet on row index {56}
# Updating {13599436.129999999} in CAR Sheet on row index {56}
# Updating {None} in CAR Sheet on row index {56}
# Updating {'=+I45-J45'} in CAR Sheet on row index {56}
# Updating {None} in CAR Sheet on row index {56}
# Updating {'=SUM(C45:H45)-I45'} in CAR Sheet on row index {56}
# Updating {'=+L45-G45-H45+K45'} in CAR Sheet on row index {56}
# Source value 211034 - Asset reval res-serv conc equipment toll road Target Vlaue 211034 - Asset reval res-serv conc equipment toll road
# Updating {1943866.5} in CAR Sheet on row index {57}
# Updating {None} in CAR Sheet on row index {57}
# Updating {None} in CAR Sheet on row index {57}
# Updating {None} in CAR Sheet on row index {57}
# Updating {None} in CAR Sheet on row index {57}
# Updating {None} in CAR Sheet on row index {57}
# Updating {1943866.5000000002} in CAR Sheet on row index {57}
# Updating {1943866.5000000002} in CAR Sheet on row index {57}
# Updating {None} in CAR Sheet on row index {57}
# Updating {'=+I46-J46'} in CAR Sheet on row index {57}
# Updating {None} in CAR Sheet on row index {57}
# Updating {'=SUM(C46:H46)-I46'} in CAR Sheet on row index {57}
# Updating {'=+L46-G46-H46+K46'} in CAR Sheet on row index {57}
# Source value 211035 - Asset reval reserve – Serv Conces Land under track Target Vlaue 211035 - Asset reval reserve – Serv Conces Land under track
# Updating {11458062.21} in CAR Sheet on row index {59}
# Updating {None} in CAR Sheet on row index {59}
# Updating {None} in CAR Sheet on row index {59}
# Updating {None} in CAR Sheet on row index {59}
# Updating {None} in CAR Sheet on row index {59}
# Updating {None} in CAR Sheet on row index {59}
# Updating {11458062.21} in CAR Sheet on row index {59}
# Updating {11458062.21} in CAR Sheet on row index {59}
# Updating {None} in CAR Sheet on row index {59}
# Updating {'=+I47-J47'} in CAR Sheet on row index {59}
# Updating {None} in CAR Sheet on row index {59}
# Updating {'=SUM(C47:H47)-I47'} in CAR Sheet on row index {59}
# Updating {'=+L47-G47-H47+K47'} in CAR Sheet on row index {59}
# Source value 211036 - Asset reval reserve - Serv Conces Tolled Rd LUR Target Vlaue 211036 - Asset reval reserve - Serv Conces Tolled Rd LUR
# Updating {514083021.04999995} in CAR Sheet on row index {60}
# Updating {None} in CAR Sheet on row index {60}
# Updating {None} in CAR Sheet on row index {60}
# Updating {None} in CAR Sheet on row index {60}
# Updating {None} in CAR Sheet on row index {60}
# Updating {None} in CAR Sheet on row index {60}
# Updating {514083021.05} in CAR Sheet on row index {60}
# Updating {514083021.05} in CAR Sheet on row index {60}
# Updating {None} in CAR Sheet on row index {60}
# Updating {'=+I48-J48'} in CAR Sheet on row index {60}
# Updating {None} in CAR Sheet on row index {60}
# Updating {'=SUM(C48:H48)-I48'} in CAR Sheet on row index {60}
# Updating {'=+L48-G48-H48+K48'} in CAR Sheet on row index {60}
# Source value H2_NA - Net assets Target Vlaue H2_NA - Net assets
# Updating {164978211042.45} in CAR Sheet on row index {66}
# Updating {11023.400000134} in CAR Sheet on row index {66}
# Updating {None} in CAR Sheet on row index {66}
# Updating {0} in CAR Sheet on row index {66}
# Updating {106430313.08} in CAR Sheet on row index {66}
# Updating {-0.02000004} in CAR Sheet on row index {66}
# Updating {165084652378.91} in CAR Sheet on row index {66}
# Updating {164978222065.85} in CAR Sheet on row index {66}
# Updating {-7.9e-08} in CAR Sheet on row index {66}
# Updating {'=+I49-J49'} in CAR Sheet on row index {66}
# Updating {None} in CAR Sheet on row index {66}
# Updating {'=SUM(C49:H49)-I49'} in CAR Sheet on row index {66}
# Updating {'=+L49-G49-H49+K49'} in CAR Sheet on row index {66}
# Source value H2_100000 - Total assets Target Vlaue H2_100000 - Total assets
# Updating {189090338270.02} in CAR Sheet on row index {67}
# Updating {235075723.5300001} in CAR Sheet on row index {67}
# Updating {None} in CAR Sheet on row index {67}
# Updating {0} in CAR Sheet on row index {67}
# Updating {-1677633336.15} in CAR Sheet on row index {67}
# Updating {-3.6e-08} in CAR Sheet on row index {67}
# Updating {187647780657.4} in CAR Sheet on row index {67}
# Updating {189325413993.55002} in CAR Sheet on row index {67}
# Updating {-1.6e-08} in CAR Sheet on row index {67}
# Updating {'=+I50-J50'} in CAR Sheet on row index {67}
# Updating {None} in CAR Sheet on row index {67}
# Updating {'=SUM(C50:H50)-I50'} in CAR Sheet on row index {67}
# Updating {'=+L50-G50-H50+K50'} in CAR Sheet on row index {67}
# Source value H2_110000 - Total current assets Target Vlaue H2_110000 - Total current assets
# Updating {7373359800.110001} in CAR Sheet on row index {68}
# Updating {97235586.80999999} in CAR Sheet on row index {68}
# Updating {None} in CAR Sheet on row index {68}
# Updating {None} in CAR Sheet on row index {68}
# Updating {-1674730744.08} in CAR Sheet on row index {68}
# Updating {-1e-09} in CAR Sheet on row index {68}
# Updating {5795864642.84} in CAR Sheet on row index {68}
# Updating {7470595386.92} in CAR Sheet on row index {68}
# Updating {-1.4e-08} in CAR Sheet on row index {68}
# Updating {'=+I51-J51'} in CAR Sheet on row index {68}
# Updating {None} in CAR Sheet on row index {68}
# Updating {'=SUM(C51:H51)-I51'} in CAR Sheet on row index {68}
# Updating {'=+L51-G51-H51+K51'} in CAR Sheet on row index {68}
# Source value H2_111000 - Cash and cash equivalents Target Vlaue H2_111000 - Cash and cash equivalents
# Updating {3584928522.1} in CAR Sheet on row index {69}
# Updating {3125079.5199999996} in CAR Sheet on row index {69}
# Updating {None} in CAR Sheet on row index {69}
# Updating {None} in CAR Sheet on row index {69}
# Updating {None} in CAR Sheet on row index {69}
# Updating {None} in CAR Sheet on row index {69}
# Updating {3588053601.62} in CAR Sheet on row index {69}
# Updating {3588053601.62} in CAR Sheet on row index {69}
# Updating {None} in CAR Sheet on row index {69}
# Updating {'=+I52-J52'} in CAR Sheet on row index {69}
# Updating {None} in CAR Sheet on row index {69}
# Updating {'=SUM(C52:H52)-I52'} in CAR Sheet on row index {69}
# Updating {'=+L52-G52-H52+K52'} in CAR Sheet on row index {69}
# Source value H2_111001 - Operating account Target Vlaue H2_111001 - Operating account
# Updating {3404628386.41} in CAR Sheet on row index {70}
# Updating {3125079.52} in CAR Sheet on row index {70}
# Updating {None} in CAR Sheet on row index {70}
# Updating {None} in CAR Sheet on row index {70}
# Updating {None} in CAR Sheet on row index {70}
# Updating {None} in CAR Sheet on row index {70}
# Updating {3407753465.9300003} in CAR Sheet on row index {70}
# Updating {3407753465.9300003} in CAR Sheet on row index {70}
# Updating {None} in CAR Sheet on row index {70}
# Updating {'=+I53-J53'} in CAR Sheet on row index {70}
# Updating {None} in CAR Sheet on row index {70}
# Updating {'=SUM(C53:H53)-I53'} in CAR Sheet on row index {70}
# Updating {'=+L53-G53-H53+K53'} in CAR Sheet on row index {70}
# Source value 111020 - Operating Bank Acct 03 - Statement Target Vlaue 111020 - Operating Bank Acct 03 - Statement
# Updating {166690912.42} in CAR Sheet on row index {73}
# Updating {None} in CAR Sheet on row index {73}
# Updating {None} in CAR Sheet on row index {73}
# Updating {None} in CAR Sheet on row index {73}
# Updating {None} in CAR Sheet on row index {73}
# Updating {None} in CAR Sheet on row index {73}
# Updating {166690912.42} in CAR Sheet on row index {73}
# Updating {166690912.42} in CAR Sheet on row index {73}
# Updating {None} in CAR Sheet on row index {73}
# Updating {'=+I54-J54'} in CAR Sheet on row index {73}
# Updating {None} in CAR Sheet on row index {73}
# Updating {'=SUM(C54:H54)-I54'} in CAR Sheet on row index {73}
# Updating {'=+L54-G54-H54+K54'} in CAR Sheet on row index {73}
# Source value 111021 - Operating Bank Acct 03 - Deposits Clearing Target Vlaue 111021 - Operating Bank Acct 03 - Deposits Clearing
# Updating {-43434319.84} in CAR Sheet on row index {74}
# Updating {None} in CAR Sheet on row index {74}
# Updating {None} in CAR Sheet on row index {74}
# Updating {None} in CAR Sheet on row index {74}
# Updating {None} in CAR Sheet on row index {74}
# Updating {None} in CAR Sheet on row index {74}
# Updating {-43434319.839999996} in CAR Sheet on row index {74}
# Updating {-43434319.839999996} in CAR Sheet on row index {74}
# Updating {None} in CAR Sheet on row index {74}
# Updating {'=+I55-J55'} in CAR Sheet on row index {74}
# Updating {None} in CAR Sheet on row index {74}
# Updating {'=SUM(C55:H55)-I55'} in CAR Sheet on row index {74}
# Updating {'=+L55-G55-H55+K55'} in CAR Sheet on row index {74}
# Source value 111022 - Operating Bank Acct 03 - Payments EFT Clearing Target Vlaue 111022 - Operating Bank Acct 03 - Payments EFT Clearing
# Updating {207724.27} in CAR Sheet on row index {75}
# Updating {None} in CAR Sheet on row index {75}
# Updating {None} in CAR Sheet on row index {75}
# Updating {None} in CAR Sheet on row index {75}
# Updating {None} in CAR Sheet on row index {75}
# Updating {None} in CAR Sheet on row index {75}
# Updating {207724.27} in CAR Sheet on row index {75}
# Updating {207724.27} in CAR Sheet on row index {75}
# Updating {None} in CAR Sheet on row index {75}
# Updating {'=+I56-J56'} in CAR Sheet on row index {75}
# Updating {None} in CAR Sheet on row index {75}
# Updating {'=SUM(C56:H56)-I56'} in CAR Sheet on row index {75}
# Updating {'=+L56-G56-H56+K56'} in CAR Sheet on row index {75}
# Source value 111100 - Operating Bank Acct 11 - Statement Target Vlaue 111100 - Operating Bank Acct 11 - Statement
# Updating {5936030.16} in CAR Sheet on row index {76}
# Updating {None} in CAR Sheet on row index {76}
# Updating {None} in CAR Sheet on row index {76}
# Updating {None} in CAR Sheet on row index {76}
# Updating {None} in CAR Sheet on row index {76}
# Updating {None} in CAR Sheet on row index {76}
# Updating {5936030.16} in CAR Sheet on row index {76}
# Updating {5936030.16} in CAR Sheet on row index {76}
# Updating {None} in CAR Sheet on row index {76}
# Updating {'=+I57-J57'} in CAR Sheet on row index {76}
# Updating {None} in CAR Sheet on row index {76}
# Updating {'=SUM(C57:H57)-I57'} in CAR Sheet on row index {76}
# Updating {'=+L57-G57-H57+K57'} in CAR Sheet on row index {76}
# Source value 111101 - Operating Bank Acct 11 - Deposits Clearing Target Vlaue 111101 - Operating Bank Acct 11 - Deposits Clearing
# Updating {-217279.75} in CAR Sheet on row index {77}
# Updating {None} in CAR Sheet on row index {77}
# Updating {None} in CAR Sheet on row index {77}
# Updating {None} in CAR Sheet on row index {77}
# Updating {None} in CAR Sheet on row index {77}
# Updating {None} in CAR Sheet on row index {77}
# Updating {-217279.75} in CAR Sheet on row index {77}
# Updating {-217279.75} in CAR Sheet on row index {77}
# Updating {None} in CAR Sheet on row index {77}
# Updating {'=+I58-J58'} in CAR Sheet on row index {77}
# Updating {None} in CAR Sheet on row index {77}
# Updating {'=SUM(C58:H58)-I58'} in CAR Sheet on row index {77}
# Updating {'=+L58-G58-H58+K58'} in CAR Sheet on row index {77}
# Source value 111102 - Operating Bank Acct 11 - Payments EFT Clearing Target Vlaue 111102 - Operating Bank Acct 11 - Payments EFT Clearing
# Updating {2198} in CAR Sheet on row index {78}
# Updating {None} in CAR Sheet on row index {78}
# Updating {None} in CAR Sheet on row index {78}
# Updating {None} in CAR Sheet on row index {78}
# Updating {None} in CAR Sheet on row index {78}
# Updating {None} in CAR Sheet on row index {78}
# Updating {2198} in CAR Sheet on row index {78}
# Updating {2198} in CAR Sheet on row index {78}
# Updating {None} in CAR Sheet on row index {78}
# Updating {'=+I59-J59'} in CAR Sheet on row index {78}
# Updating {None} in CAR Sheet on row index {78}
# Updating {'=SUM(C59:H59)-I59'} in CAR Sheet on row index {78}
# Updating {'=+L59-G59-H59+K59'} in CAR Sheet on row index {78}
# Source value 111110 - Operating Bank Acct 12 - Statement Target Vlaue 111110 - Operating Bank Acct 12 - Statement
# Updating {5829766.7} in CAR Sheet on row index {79}
# Updating {None} in CAR Sheet on row index {79}
# Updating {None} in CAR Sheet on row index {79}
# Updating {None} in CAR Sheet on row index {79}
# Updating {None} in CAR Sheet on row index {79}
# Updating {None} in CAR Sheet on row index {79}
# Updating {5829766.699999999} in CAR Sheet on row index {79}
# Updating {5829766.699999999} in CAR Sheet on row index {79}
# Updating {None} in CAR Sheet on row index {79}
# Updating {'=+I60-J60'} in CAR Sheet on row index {79}
# Updating {None} in CAR Sheet on row index {79}
# Updating {'=SUM(C60:H60)-I60'} in CAR Sheet on row index {79}
# Updating {'=+L60-G60-H60+K60'} in CAR Sheet on row index {79}
# Source value 111111 - Operating Bank Acct 12 - Deposits Clearing Target Vlaue 111111 - Operating Bank Acct 12 - Deposits Clearing
# Updating {-4529} in CAR Sheet on row index {80}
# Updating {None} in CAR Sheet on row index {80}
# Updating {None} in CAR Sheet on row index {80}
# Updating {None} in CAR Sheet on row index {80}
# Updating {None} in CAR Sheet on row index {80}
# Updating {None} in CAR Sheet on row index {80}
# Updating {-4529} in CAR Sheet on row index {80}
# Updating {-4529} in CAR Sheet on row index {80}
# Updating {None} in CAR Sheet on row index {80}
# Updating {'=+I61-J61'} in CAR Sheet on row index {80}
# Updating {None} in CAR Sheet on row index {80}
# Updating {'=SUM(C61:H61)-I61'} in CAR Sheet on row index {80}
# Updating {'=+L61-G61-H61+K61'} in CAR Sheet on row index {80}
# Source value 111023 - Operating Bank Acct 03 - Payments CHQ Clearing Target Vlaue 111023 - Operating Bank Acct 03 - Payments CHQ Clearing
# Updating {90} in CAR Sheet on row index {81}
# Updating {None} in CAR Sheet on row index {81}
# Updating {None} in CAR Sheet on row index {81}
# Updating {None} in CAR Sheet on row index {81}
# Updating {None} in CAR Sheet on row index {81}
# Updating {None} in CAR Sheet on row index {81}
# Updating {90} in CAR Sheet on row index {81}
# Updating {90} in CAR Sheet on row index {81}
# Updating {None} in CAR Sheet on row index {81}
# Updating {'=+I62-J62'} in CAR Sheet on row index {81}
# Updating {None} in CAR Sheet on row index {81}
# Updating {'=SUM(C62:H62)-I62'} in CAR Sheet on row index {81}
# Updating {'=+L62-G62-H62+K62'} in CAR Sheet on row index {81}
# Source value 111210 - Fees & DChq Bank Acct 02 - Statement Target Vlaue 111210 - Fees & DChq Bank Acct 02 - Statement
# Updating {-1218287.99} in CAR Sheet on row index {82}
# Updating {None} in CAR Sheet on row index {82}
# Updating {None} in CAR Sheet on row index {82}
# Updating {None} in CAR Sheet on row index {82}
# Updating {None} in CAR Sheet on row index {82}
# Updating {None} in CAR Sheet on row index {82}
# Updating {-1218287.99} in CAR Sheet on row index {82}
# Updating {-1218287.99} in CAR Sheet on row index {82}
# Updating {None} in CAR Sheet on row index {82}
# ...
# Updating {'=SUM(C246:H246)-I246'} in CAR Sheet on row index {304}
# Updating {'=+L246-G246-H246+K246'} in CAR Sheet on row index {304}
# Source value 125754 - SCA-Rolling stock Target Vlaue 125754 - SCA-Rolling stock
# Updating {707041603.92} in CAR Sheet on row index {306}
# Updating {None} in CAR Sheet on row index {306}
# Updating {None} in CAR Sheet on row index {306}
# Updating {None} in CAR Sheet on row index {306}
# Updating {None} in CAR Sheet on row index {306}
# Updating {None} in CAR Sheet on row index {306}
# Updating {707041603.92} in CAR Sheet on row index {306}
# Updating {707041603.92} in CAR Sheet on row index {306}
# Updating {None} in CAR Sheet on row index {306}
# Updating {'=+I247-J247'} in CAR Sheet on row index {306}
# Updating {None} in CAR Sheet on row index {306}
# Updating {'=SUM(C247:H247)-I247'} in CAR Sheet on row index {306}
# Updating {'=+L247-G247-H247+K247'} in CAR Sheet on row index {306}
# Source value H2_125734 - Accumulated depreciation and impairment (at fair value) Target Vlaue H2_125734 - Accumulated depreciation and impairment (at fair value)
# Updating {-113511923.5} in CAR Sheet on row index {307}
# Updating {None} in CAR Sheet on row index {307}
# Updating {None} in CAR Sheet on row index {307}
# Updating {None} in CAR Sheet on row index {307}
# Updating {None} in CAR Sheet on row index {307}
# Updating {None} in CAR Sheet on row index {307}
# Updating {-113511923.5} in CAR Sheet on row index {307}
# Updating {-113511923.5} in CAR Sheet on row index {307}
# Updating {None} in CAR Sheet on row index {307}
# Updating {'=+I248-J248'} in CAR Sheet on row index {307}
# Updating {None} in CAR Sheet on row index {307}
# Updating {'=SUM(C248:H248)-I248'} in CAR Sheet on row index {307}
# Updating {'=+L248-G248-H248+K248'} in CAR Sheet on row index {307}
# Source value 125301 - Accumulated Depreciation - Rolling Stock Target Vlaue 125301 - Accumulated Depreciation - Rolling Stock
# Updating {-7915415.4} in CAR Sheet on row index {308}
# Updating {None} in CAR Sheet on row index {308}
# Updating {None} in CAR Sheet on row index {308}
# Updating {None} in CAR Sheet on row index {308}
# Updating {None} in CAR Sheet on row index {308}
# Updating {None} in CAR Sheet on row index {308}
# Updating {-7915415.4} in CAR Sheet on row index {308}
# Updating {-7915415.4} in CAR Sheet on row index {308}
# Updating {None} in CAR Sheet on row index {308}
# Updating {'=+I249-J249'} in CAR Sheet on row index {308}
# Updating {None} in CAR Sheet on row index {308}
# Updating {'=SUM(C249:H249)-I249'} in CAR Sheet on row index {308}
# Updating {'=+L249-G249-H249+K249'} in CAR Sheet on row index {308}
# Source value 125756 - SCA-Rolling stock accumulated depreciation Target Vlaue 125756 - SCA-Rolling stock accumulated depreciation
# Updating {-105596508.1} in CAR Sheet on row index {311}
# Updating {None} in CAR Sheet on row index {311}
# Updating {None} in CAR Sheet on row index {311}
# Updating {None} in CAR Sheet on row index {311}
# Updating {None} in CAR Sheet on row index {311}
# Updating {None} in CAR Sheet on row index {311}
# Updating {-105596508.1} in CAR Sheet on row index {311}
# Updating {-105596508.1} in CAR Sheet on row index {311}
# Updating {None} in CAR Sheet on row index {311}
# Updating {'=+I250-J250'} in CAR Sheet on row index {311}
# Updating {None} in CAR Sheet on row index {311}
# Updating {'=SUM(C250:H250)-I250'} in CAR Sheet on row index {311}
# Updating {'=+L250-G250-H250+K250'} in CAR Sheet on row index {311}
# Source value H2_125716 - Asset under Construction - Rolling Stock Target Vlaue H2_125716 - Asset under Construction - Rolling Stock
# Updating {111689213.55} in CAR Sheet on row index {312}
# Updating {None} in CAR Sheet on row index {312}
# Updating {None} in CAR Sheet on row index {312}
# Updating {None} in CAR Sheet on row index {312}
# Updating {None} in CAR Sheet on row index {312}
# Updating {None} in CAR Sheet on row index {312}
# Updating {111689213.55} in CAR Sheet on row index {312}
# Updating {111689213.55} in CAR Sheet on row index {312}
# Updating {None} in CAR Sheet on row index {312}
# Updating {'=+I251-J251'} in CAR Sheet on row index {312}
# Updating {None} in CAR Sheet on row index {312}
# Updating {'=SUM(C251:H251)-I251'} in CAR Sheet on row index {312}
# Updating {'=+L251-G251-H251+K251'} in CAR Sheet on row index {312}
# Source value 125735 - Asset under Construction - Rolling Stock Target Vlaue 125735 - Asset under Construction - Rolling Stock
# Updating {35171914.01} in CAR Sheet on row index {313}
# Updating {None} in CAR Sheet on row index {313}
# Updating {None} in CAR Sheet on row index {313}
# Updating {None} in CAR Sheet on row index {313}
# Updating {None} in CAR Sheet on row index {313}
# Updating {None} in CAR Sheet on row index {313}
# Updating {35171914.01} in CAR Sheet on row index {313}
# Updating {35171914.01} in CAR Sheet on row index {313}
# Updating {None} in CAR Sheet on row index {313}
# Updating {'=+I252-J252'} in CAR Sheet on row index {313}
# Updating {None} in CAR Sheet on row index {313}
# Updating {'=SUM(C252:H252)-I252'} in CAR Sheet on row index {313}
# Updating {'=+L252-G252-H252+K252'} in CAR Sheet on row index {313}
# Source value 125739 - AUC - SCA Rolling Stock NON FAR Target Vlaue 125739 - AUC - SCA Rolling Stock NON FAR
# Updating {21600660.22} in CAR Sheet on row index {314}
# Updating {None} in CAR Sheet on row index {314}
# Updating {None} in CAR Sheet on row index {314}
# Updating {None} in CAR Sheet on row index {314}
# Updating {None} in CAR Sheet on row index {314}
# Updating {None} in CAR Sheet on row index {314}
# Updating {21600660.22} in CAR Sheet on row index {314}
# Updating {21600660.22} in CAR Sheet on row index {314}
# Updating {None} in CAR Sheet on row index {314}
# Updating {'=+I253-J253'} in CAR Sheet on row index {314}
# Updating {None} in CAR Sheet on row index {314}
# Updating {'=SUM(C253:H253)-I253'} in CAR Sheet on row index {314}
# Updating {'=+L253-G253-H253+K253'} in CAR Sheet on row index {314}
# Source value 125734 - AUC - Rolling Stock NON FAR Target Vlaue 125734 - AUC - Rolling Stock NON FAR
# Updating {54916639.32} in CAR Sheet on row index {315}
# Updating {None} in CAR Sheet on row index {315}
# Updating {None} in CAR Sheet on row index {315}
# Updating {None} in CAR Sheet on row index {315}
# Updating {None} in CAR Sheet on row index {315}
# Updating {None} in CAR Sheet on row index {315}
# Updating {54916639.31999999} in CAR Sheet on row index {315}
# Updating {54916639.31999999} in CAR Sheet on row index {315}
# Updating {None} in CAR Sheet on row index {315}
# Updating {'=+I254-J254'} in CAR Sheet on row index {315}
# Updating {None} in CAR Sheet on row index {315}
# Updating {'=SUM(C254:H254)-I254'} in CAR Sheet on row index {315}
# Updating {'=+L254-G254-H254+K254'} in CAR Sheet on row index {315}
# Source value H2_125740 - Buses Target Vlaue H2_125740 - Buses
# Updating {329998683.72999996} in CAR Sheet on row index {316}
# Updating {None} in CAR Sheet on row index {316}
# Updating {None} in CAR Sheet on row index {316}
# Updating {None} in CAR Sheet on row index {316}
# Updating {None} in CAR Sheet on row index {316}
# Updating {None} in CAR Sheet on row index {316}
# Updating {329998683.72999996} in CAR Sheet on row index {316}
# Updating {329998683.72999996} in CAR Sheet on row index {316}
# Updating {None} in CAR Sheet on row index {316}
# Updating {'=+I255-J255'} in CAR Sheet on row index {316}
# Updating {None} in CAR Sheet on row index {316}
# Updating {'=SUM(C255:H255)-I255'} in CAR Sheet on row index {316}
# Updating {'=+L255-G255-H255+K255'} in CAR Sheet on row index {316}
# Source value H2_125749 - Buses (excl. AUC) Target Vlaue H2_125749 - Buses (excl. AUC)
# Updating {1118902233.69} in CAR Sheet on row index {317}
# Updating {None} in CAR Sheet on row index {317}
# Updating {None} in CAR Sheet on row index {317}
# Updating {None} in CAR Sheet on row index {317}
# Updating {None} in CAR Sheet on row index {317}
# Updating {None} in CAR Sheet on row index {317}
# Updating {1118902233.69} in CAR Sheet on row index {317}
# Updating {1118902233.69} in CAR Sheet on row index {317}
# Updating {None} in CAR Sheet on row index {317}
# Updating {'=+I256-J256'} in CAR Sheet on row index {317}
# Updating {None} in CAR Sheet on row index {317}
# Updating {'=SUM(C256:H256)-I256'} in CAR Sheet on row index {317}
# Updating {'=+L256-G256-H256+K256'} in CAR Sheet on row index {317}
# Source value H2_125742 - Gross carrying value (at fair value) Target Vlaue H2_125742 - Gross carrying value (at fair value)
# Updating {1118902233.69} in CAR Sheet on row index {318}
# Updating {None} in CAR Sheet on row index {318}
# Updating {None} in CAR Sheet on row index {318}
# Updating {None} in CAR Sheet on row index {318}
# Updating {None} in CAR Sheet on row index {318}
# Updating {None} in CAR Sheet on row index {318}
# Updating {1118902233.69} in CAR Sheet on row index {318}
# Updating {1118902233.69} in CAR Sheet on row index {318}
# Updating {None} in CAR Sheet on row index {318}
# Updating {'=+I257-J257'} in CAR Sheet on row index {318}
# Updating {None} in CAR Sheet on row index {318}
# Updating {'=SUM(C257:H257)-I257'} in CAR Sheet on row index {318}
# Updating {'=+L257-G257-H257+K257'} in CAR Sheet on row index {318}
# Source value 125200 - Buses Target Vlaue 125200 - Buses
# Updating {1118902233.68} in CAR Sheet on row index {319}
# Updating {None} in CAR Sheet on row index {319}
# Updating {None} in CAR Sheet on row index {319}
# Updating {None} in CAR Sheet on row index {319}
# Updating {None} in CAR Sheet on row index {319}
# Updating {None} in CAR Sheet on row index {319}
# Updating {1118902233.6799998} in CAR Sheet on row index {319}
# Updating {1118902233.6799998} in CAR Sheet on row index {319}
# Updating {None} in CAR Sheet on row index {319}
# Updating {'=+I258-J258'} in CAR Sheet on row index {319}
# Updating {None} in CAR Sheet on row index {319}
# Updating {'=SUM(C258:H258)-I258'} in CAR Sheet on row index {319}
# Updating {'=+L258-G258-H258+K258'} in CAR Sheet on row index {319}
# Source value 125202 - Buses - Owned  -non-control account Target Vlaue 125202 - Buses - Owned  -non-control account
# Updating {0.01} in CAR Sheet on row index {320}
# Updating {None} in CAR Sheet on row index {320}
# Updating {None} in CAR Sheet on row index {320}
# Updating {None} in CAR Sheet on row index {320}
# Updating {None} in CAR Sheet on row index {320}
# Updating {None} in CAR Sheet on row index {320}
# Updating {0.01} in CAR Sheet on row index {320}
# Updating {0.01} in CAR Sheet on row index {320}
# Updating {None} in CAR Sheet on row index {320}
# Updating {'=+I259-J259'} in CAR Sheet on row index {320}
# Updating {None} in CAR Sheet on row index {320}
# Updating {'=SUM(C259:H259)-I259'} in CAR Sheet on row index {320}
# Updating {'=+L259-G259-H259+K259'} in CAR Sheet on row index {320}
# Source value H2_125745 - Asset under construction- buses Target Vlaue H2_125745 - Asset under construction- buses
# Updating {73888727.5} in CAR Sheet on row index {321}
# Updating {None} in CAR Sheet on row index {321}
# Updating {None} in CAR Sheet on row index {321}
# Updating {None} in CAR Sheet on row index {321}
# Updating {None} in CAR Sheet on row index {321}
# Updating {None} in CAR Sheet on row index {321}
# Updating {73888727.5} in CAR Sheet on row index {321}
# Updating {73888727.5} in CAR Sheet on row index {321}
# Updating {None} in CAR Sheet on row index {321}
# Updating {'=+I260-J260'} in CAR Sheet on row index {321}
# Updating {None} in CAR Sheet on row index {321}
# Updating {'=SUM(C260:H260)-I260'} in CAR Sheet on row index {321}
# Updating {'=+L260-G260-H260+K260'} in CAR Sheet on row index {321}
# Source value 125725 - Asset under Construction - Buses Target Vlaue 125725 - Asset under Construction - Buses
# Updating {81310493.11} in CAR Sheet on row index {322}
# Updating {None} in CAR Sheet on row index {322}
# Updating {None} in CAR Sheet on row index {322}
# Updating {None} in CAR Sheet on row index {322}
# Updating {None} in CAR Sheet on row index {322}
# Updating {None} in CAR Sheet on row index {322}
# Updating {81310493.11} in CAR Sheet on row index {322}
# Updating {81310493.11} in CAR Sheet on row index {322}
# Updating {None} in CAR Sheet on row index {322}
# Updating {'=+I261-J261'} in CAR Sheet on row index {322}
# Updating {None} in CAR Sheet on row index {322}
# Updating {'=SUM(C261:H261)-I261'} in CAR Sheet on row index {322}
# Updating {'=+L261-G261-H261+K261'} in CAR Sheet on row index {322}
# Source value 125726 - AUC  - Buses NON FAR Target Vlaue 125726 - AUC  - Buses NON FAR
# Updating {-7421765.61} in CAR Sheet on row index {323}
# Updating {None} in CAR Sheet on row index {323}
# Updating {None} in CAR Sheet on row index {323}
# Updating {None} in CAR Sheet on row index {323}
# Updating {None} in CAR Sheet on row index {323}
# Updating {None} in CAR Sheet on row index {323}
# Updating {-7421765.61} in CAR Sheet on row index {323}
# Updating {-7421765.61} in CAR Sheet on row index {323}
# Updating {None} in CAR Sheet on row index {323}
# Updating {'=+I262-J262'} in CAR Sheet on row index {323}
# Updating {None} in CAR Sheet on row index {323}
# Updating {'=SUM(C262:H262)-I262'} in CAR Sheet on row index {323}
# Updating {'=+L262-G262-H262+K262'} in CAR Sheet on row index {323}
# Source value H2_125744 - Accumulated depreciation and impairment - Buses Target Vlaue H2_125744 - Accumulated depreciation and impairment - Buses
# Updating {-862792277.46} in CAR Sheet on row index {324}
# Updating {None} in CAR Sheet on row index {324}
# Updating {None} in CAR Sheet on row index {324}
# Updating {None} in CAR Sheet on row index {324}
# Updating {None} in CAR Sheet on row index {324}
# Updating {None} in CAR Sheet on row index {324}
# Updating {-862792277.46} in CAR Sheet on row index {324}
# Updating {-862792277.46} in CAR Sheet on row index {324}
# Updating {None} in CAR Sheet on row index {324}
# Updating {'=+I263-J263'} in CAR Sheet on row index {324}
# Updating {None} in CAR Sheet on row index {324}
# Updating {'=SUM(C263:H263)-I263'} in CAR Sheet on row index {324}
# Updating {'=+L263-G263-H263+K263'} in CAR Sheet on row index {324}
# Source value 125201 - Accumulated Depreciation - Buses Target Vlaue 125201 - Accumulated Depreciation - Buses
# Updating {-862792277.5} in CAR Sheet on row index {325}
# Updating {None} in CAR Sheet on row index {325}
# Updating {None} in CAR Sheet on row index {325}
# Updating {None} in CAR Sheet on row index {325}
# Updating {None} in CAR Sheet on row index {325}
# Updating {None} in CAR Sheet on row index {325}
# Updating {-862792277.5} in CAR Sheet on row index {325}
# Updating {-862792277.5} in CAR Sheet on row index {325}
# Updating {None} in CAR Sheet on row index {325}
# Updating {'=+I264-J264'} in CAR Sheet on row index {325}
# Updating {None} in CAR Sheet on row index {325}
# Updating {'=SUM(C264:H264)-I264'} in CAR Sheet on row index {325}
# Updating {'=+L264-G264-H264+K264'} in CAR Sheet on row index {325}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-c47c9d339180> in <cell line: 48>()
#      60             else:
#      61               match_row_idx = 0
# ---> 62               for row_trgt_index, row_trgt in enumerate(CAR_sheet.iter_rows(min_row=4), start=1):
#      63                 if match_row_idx: #Exit from row loop when match found
#      64                   break
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/worksheet.py in iter_rows(self, min_row, max_row, min_col, max_col, values_only)
#     441         min_col = min_col or 1
#     442         min_row = min_row or 1
# --> 443         max_col = max_col or self.max_column
#     444         max_row = max_row or self.max_row
#     445
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/worksheet.py in max_column(self)
#     376         max_col = 1
#     377         if self._cells:
# --> 378             cols = set(c[1] for c in self._cells)
#     379             max_col = max(cols)
#     380         return max_col
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/worksheet.py in <genexpr>(.0)
#     376         max_col = 1
#     377         if self._cells:
# --> 378             cols = set(c[1] for c in self._cells)
#     379             max_col = max(cols)
#     380         return max_col
#
# KeyboardInterrupt:

# %%
#**************************************************************************************This is a version that retains the formulas**************************************************************************
from numpy.core.multiarray import concatenate
import pandas as pd
import openpyxl
import numpy as np
import re
from openpyxl.styles import PatternFill, Border, Side, Alignment, Protection, Font

wb = openpyxl.load_workbook('/content/DoT (Cluster) AR.xlsx', data_only=False, rich_text=True)
indx_sheet = wb['Index']
add_col_idx = indx_sheet.max_column + 1
#sheet_names = wb.sheetnames
# Use the following SWITCH to define "scope" of the script. False = Do not apply, True = Apply
Font_Size_Switch = True
Row_Height_Switch = True
Border_Switch = True # False will not remove vertical borders
Column_Width_Switch = True
#print(wb.sheetnames)#
for title in wb.sheetnames:
  print("Start of", title)
  ws = wb[title]
#  hidden_flg = ws.sheet_state
  for name_range in wb.defined_names.values():
   char_idx = name_range.attr_text.find('!')
   #print(ws.sheet_state)
   if ws.title==name_range.attr_text[:char_idx] and ws.sheet_state == 'visible':
    #named_array = wb.defined_names[title]
    #print("I am processing",ws.title)
    cell_range=name_range.attr_text
    #print(cell_range)
    start_cell, end_cell = cell_range.split(':')
    sheet, start_cell = start_cell.split('!')
    start_cell = start_cell.replace("$","")
    end_cell = end_cell.replace("$","")
    start_row, start_col = openpyxl.utils.cell.coordinate_to_tuple(start_cell)
    end_row, end_col= openpyxl.utils.cell.coordinate_to_tuple(end_cell)
    row_height = 14.5
    index = 0
    num_count = 0
    cnt_nts = 0
    hidden_columns = []
    notes_exists = False
    min=0
    max=0
    h_min=0
    h_max=0
    true_end = end_col
    hiddenList=[]
    groupedList=[]

    #Thi block loops on rows defined in the named range to find Notes colum
    for row in ws.iter_rows():
        for row_cell in row:
         if row_cell.value =="Notes" or row_cell.value =="Note":
          notes_exists=True
          cnt_nts = row_cell.col_idx
          print("Notes Index position",cnt_nts)
          break
    # This block determines number of numeric columns

    for col_h in range(start_col , end_col + 1):
        sheet_cell = ws.cell(row=end_row, column=col_h)
        #print("sheet scope", sheet_cell.value, col_h, bool )
        #print(col_h, ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min, ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max, ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].hidden, ws.title )
        if col_h in groupedList: #col_h == true_end and not ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min:
          ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min = col_h
          ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max = col_h
          num_count += 1
          print("I am columns", col_h,"I am in condition 0")
          continue
        if col_h in hiddenList: #min and max and col_h > min and col_h <= max and not ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].hidden :
             print("I am column", col_h, "and I am in condition 1")
             continue
        elif not ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].hidden and ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min == ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max: #This is a default scenario for visible columns
             #print(type(sheet_cell.value))
             if (re.match(r'^#',last_row_values.number_format)) and col_h != cnt_nts: # isinstance(sheet_cell.value, (int, float)): #
                  num_count += 1
                  print("I am column", col_h, "and I am in condition 2")
        elif ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].hidden and ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min != ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max:   #This capture the first cell of hidden cell range
              hiddenList.clear()
              for i in range(ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min, ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max + 1):
                            hiddenList.append(i)
              h_min = ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min
              h_max = ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max
              print("I am column", col_h, "and I am in condition 3", hiddenList )
              continue
        elif not ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].hidden and ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min != ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max:   #This captures any grouped columns that have min & max defined None and are visible in excel
              groupedList.clear()
              for i in range(ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min, ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max + 1):
                            groupedList.append(i)
              min = ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min
              max = ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max
              num_count += 1
              print("I am column", col_h, "and I am in condition 4",min,max, groupedList)

    print("Numeric columns", num_count, ws.title)


    #Loop on rows defined in the named range
    for row in range(start_row, end_row + 1):
      index += 1
      if Row_Height_Switch is True:
        #set the row height to 14.5
        ws.row_dimensions[row].height=row_height
        Is_hidden = ws.row_dimensions[row].hidden
      groupedList.clear()
      hiddenList.clear()
      col_index=start_col + 1
# Loop on columns starting from the range defined in Named Range
      for col in range(start_col , end_col + 1):
       sheet_cell = ws.cell(row=row, column=col)
       if index==1: #Row 1
        last_row_values = ws.cell(row=end_row, column=col)
#******This block is to hide columns that come as visible due to excel functionality to Group columns that are hidden consecutively hidden********
        if col in groupedList: #col_h == true_end and not ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min:
          fstyle_bold = sheet_cell.font.bold
          fstyle_italic = sheet_cell.font.italic
        if col_h in hiddenList: #min and max and col_h > min and col_h <= max and not ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].hidden :
          ws.column_dimensions[openpyxl.utils.get_column_letter(col)].hidden = True
          continue
        elif not ws.column_dimensions[openpyxl.utils.get_column_letter(col)].hidden and ws.column_dimensions[openpyxl.utils.get_column_letter(col)].min == ws.column_dimensions[openpyxl.utils.get_column_letter(col)].max: #This is a default scenario for visible columns
          fstyle_bold = sheet_cell.font.bold
          fstyle_italic = sheet_cell.font.italic
        elif ws.column_dimensions[openpyxl.utils.get_column_letter(col)].hidden and ws.column_dimensions[openpyxl.utils.get_column_letter(col)].min != ws.column_dimensions[openpyxl.utils.get_column_letter(col)].max:   #This capture the first cell of hidden cell range
          hiddenList.clear()
          for i in range(ws.column_dimensions[openpyxl.utils.get_column_letter(col)].min, ws.column_dimensions[openpyxl.utils.get_column_letter(col)].max + 1):
                            hiddenList.append(i)
          print("I am column", col_h, "and I am in condition 3", hiddenList )
          continue
        elif not ws.column_dimensions[openpyxl.utils.get_column_letter(col)].hidden and ws.column_dimensions[openpyxl.utils.get_column_letter(col)].min != ws.column_dimensions[openpyxl.utils.get_column_letter(col)].max:   #This captures any grouped columns that have min & max defined None and are visible in excel
          groupedList.clear()
          for i in range(ws.column_dimensions[openpyxl.utils.get_column_letter(col)].min, ws.column_dimensions[openpyxl.utils.get_column_letter(col)].max + 1):
                            groupedList.append(i)
          fstyle_bold = sheet_cell.font.bold
          fstyle_italic = sheet_cell.font.italic
          print("I am column", col_h, "and I am in condition 4",min,max, groupedList)
#********End of block*************

        if not Font_Size_Switch:
            font_size = sheet_cell.font.size
        else:
            # Set the font SIZE based on numeric columns
            if num_count <= 8:
              font_size = 9
            elif num_count in (9, 10):
              font_size = 8
            else:
              font_size = 7

 #******This block sets the Column Width at row of the defined range as this block is executed within Index 1 if condition above
        if Column_Width_Switch is True:
          if notes_exists and col==col_index:
              if num_count == 1:
                   col_width = 8.91
              elif num_count == 2:
                   col_width = 8.91
              elif num_count==3:
                   col_width = 8.91
              elif num_count==4:
                   col_width=8.18
              elif num_count==5:
                   col_width=7.82
              elif num_count==6:
                   col_width=8.91
              elif num_count==7:
                   col_width=8.55
              elif num_count==8:
                   col_width=8.18
              elif num_count==9:
                   col_width=7.82
              elif num_count==10:
                   col_width=7
              elif num_count==11:
                   col_width=6.18
              else:
                   col_width=6.18
              print("I am using", col_width, "for Notes columns in sheet", ws.title)
                # now update the worksheet with above column widths
              ws.column_dimensions[openpyxl.utils.get_column_letter(col)].width=col_width
          if col==start_col and not notes_exists: #This is for column 1
                #Set the default column WIDTH of first colum based on how many numeric columns
                if num_count == 1:
                    col_width = 65.55 + 8.91
                elif num_count == 2:
                    col_width = 53.55 + 8.91
                elif num_count==3:
                    col_width = 41.45 + 8.91
                elif num_count==4:
                    col_width=34.18 + 8.18
                elif num_count==5:
                    col_width=26.09 + 7.82
                elif num_count==6:
                    col_width=49 + 8.91
                elif num_count==7:
                    col_width=40.82 + 8.55
                elif num_count==8:
                    col_width=33.64 + 8.18
                elif num_count==9:
                    col_width=27.55 + 7.82
                elif num_count==10:
                    col_width=27.91 + 7
                elif num_count==11:
                    col_width=61.4 + 6.18
                else:
                    col_width=21.64 + 6.18
                ws.column_dimensions[openpyxl.utils.get_column_letter(col)].width=col_width
                # set the column widths in worksheet
                print(col, col_width, "for label")
          if col==start_col and notes_exists: #This is for column 1
                #Set the default column WIDTH of first colum based on how many numeric columns
                if num_count == 1:
                    col_width = 65.55
                elif num_count == 2:
                    col_width = 53.55
                elif num_count==3:
                    col_width = 41.45
                elif num_count==4:
                    col_width=34.18
                elif num_count==5:
                    col_width=26.09
                elif num_count==6:
                    col_width=49
                elif num_count==7:
                    col_width=40.82
                elif num_count==8:
                    col_width=33.64
                elif num_count==9:
                    col_width=27.55
                elif num_count==10:
                    col_width=27.91
                elif num_count==11:
                    col_width=61.4
                else:
                    col_width=21.64
                # set the column widths in worksheet
                print(col, col_width, "for label")
                ws.column_dimensions[openpyxl.utils.get_column_letter(col)].width=col_width
                print(ws.column_dimensions[openpyxl.utils.get_column_letter(col)].width)
          if (re.match(r'^#',last_row_values.number_format)) and col!=cnt_nts: #isinstance(last_row_values, (int, float)): #
                #Set the default column WIDTH for numeric column based on how many amount columns are in sheet
                if num_count <= 3 or num_count==6:
                   col_width = 11.45
                elif num_count == 4:
                   col_width = 10.36
                elif num_count==5:
                   col_width = 9.91
                elif num_count==7:
                   col_width=10.91
                elif num_count==8:
                   col_width=10.36
                elif num_count==9:
                   col_width=9.64
                elif num_count==10:
                   col_width=8.82
                else:
                   col_width=7.91
                print("I am using", col_width, "for amount")
                # set the column widths in worksheet
                ws.column_dimensions[openpyxl.utils.get_column_letter(col)].width=col_width
        elif not Column_Width_Switch:
          ws.column_dimensions[openpyxl.utils.get_column_letter(col)].width=ws.column_dimensions[openpyxl.utils.get_column_letter(col)].width
#********This block sets the font size and formatting properties of cell***************
       font_prpts = {}
       if Font_Size_Switch and index == 1:
         #set the font properties for row 1
         fstyle_bold = sheet_cell.font.bold
         fstyle_italic = sheet_cell.font.italic
         fstyle_size = sheet_cell.font.size
         #print("I am setting", fstyle_bold, "font properties of", row, col)
         font_prpts= { "name": "Arial",
              "size": fstyle_size,
              "bold": fstyle_bold,
              "italic": fstyle_italic,
              "vertAlign":"baseline",
              "underline":"none",
              "strike":False }
         font = Font(**font_prpts)
         sheet_cell.font = font
       elif Font_Size_Switch and index != 1:
         fstyle_bold = sheet_cell.font.bold
         fstyle_italic = sheet_cell.font.italic
         fstyle_size = sheet_cell.font.size
         #print("I am setting", fstyle_bold, "font properties of", row, col)
        #set the font properties for remaining rows
         font_prpts= { "name": "Arial",
              "size": fstyle_size if not Font_Size_Switch else 9.0,
              "bold": fstyle_bold,
              "italic": fstyle_italic,
              "vertAlign":"baseline",
              "underline":"none",
              "strike":False }
       font = Font(**font_prpts)
       sheet_cell.font = font
#*********This block sets the formatting properties*****************#
       if Border_Switch == True and not 'PPE' in ws.title:
          if sheet_cell.border.left.border_style == "thin" or sheet_cell.border.right.border_style == "thin":
             sheet_cell.border.left.border_style = 'none'
             sheet_cell.border.right.border_style = 'none'
             print("a border is removed at cell location", col, ws.title)
       if row == start_row and sheet_cell.value=="Notes" or sheet_cell.value=="Note":
             sheet_cell.alignment = Alignment(horizontal='right',
                                              vertical = 'bottom',
                                              wrap_text=True)
       elif row == start_row and sheet_cell.value!="Notes" or sheet_cell.value=="Note":
               sheet_cell.alignment = Alignment(horizontal='right',
                                                vertical = 'bottom',
                                                wrap_text=True)
       elif row != start_row and col == start_col:
             cell_index = sheet_cell.alignment.indent
             sheet_cell.alignment = Alignment(horizontal='left',
                                                vertical = 'bottom',
                                                wrap_text=True,
                                                indent=cell_index)
       elif col==col_index and notes_exists:
               sheet_cell.alignment = Alignment(horizontal='right',
                                                vertical = 'bottom',
                                                wrap_text=True)
               sheet_cell.number_format = 'General'

       else:
               sheet_cell.alignment = Alignment(horizontal='right',
                                                vertical = 'bottom',
                                                wrap_text=False)

  for irow in indx_sheet.iter_rows(min_row=2, max_row=indx_sheet.max_row, min_col=1, max_col=indx_sheet.max_column):
    for icell in irow:
      if icell.value==ws.title:
        indx_sheet.cell(row=icell.row, column=add_col_idx, value=num_count)

wb.save('test.xlsx')
