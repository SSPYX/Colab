# %% [markdown]
# <a href="https://colab.research.google.com/github/SSPYX/Colab/blob/main/CAR_Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy.core.multiarray import concatenate
import pandas as pd
import openpyxl
import numpy as np
import re
from openpyxl.styles import PatternFill, Border, Side, Alignment, Protection, Font

wb = openpyxl.load_workbook('/content/Copy of CAR Report DoT.xlsx', data_only=False, rich_text=True)
#sheet_names = wb.sheetnames
# Use the following SWITCH to define "scope" of the script. False = Do not apply, True = Apply
Font_Size_Switch = True
Row_Height_Switch = True
Border_Switch = False # False will not remove vertical borders
Column_Width_Switch = True
#print(wb.sheetnames)#
#for title in wb.sheetnames:
  #print("Start of", title)
ws = wb['1000']
CAR_sheet = wb['CAR']

#print(ws.title)
#  hidden_flg = ws.sheet_state
#  for row_index, row in enumerate(ws.iter_rows(min_row=0, max_row=1), start=1): # This is looping on row 1 in individual sheet
#    for cell in row:
      #print(cell.value)
#      if cell.value:
match_row_idx = 0
min_row = 4
for heading_row in CAR_sheet.iter_rows(min_row=3, max_row=3):
  header_row = heading_row
  #print(header_row)
for row_index, row in enumerate(ws.iter_rows(min_row=3, min_col = 2), start=1): # This loops on row starting from 3 in source worksheet
  value_found = None
  for cell in row:  #This loops on each column in a row in source worksheet
          lookup_value = cell.value
          column_heading = ws.cell(row=1, column=cell.col_idx) #To-do
          for row_trgt_index, row_trgt in enumerate(CAR_sheet.iter_rows(min_row=min_row, min_col = 3), start=1): #This loops on rows of Target sheet
            if value_found == 'X':
              break
            else:
              for col_trgt in row_trgt: #Loop over all columns in each row
                if lookup_value==col_trgt.value:
                    print("Lookup Vlaue", lookup_value, "Target Value",  col_trgt.value)
    #              print(lookup_value)
                    value_found='X'
                    min_row = row_trgt_index + 1
                    break
#      elif cell.col_idx == 1:
#         continue
#      else:
#         break


#wb.save('test.xlsx')
# Out:
# Lookup Vlaue H2_BS - Total Balance Sheet Target Value H2_BS - Total Balance Sheet
# Lookup Vlaue H2_200000 - Total equity Target Value H2_200000 - Total equity
# Lookup Vlaue H2_220000 - Accumulated funds Target Value H2_220000 - Accumulated funds
# Lookup Vlaue 220010 - Retained Surplus(Accum Losses) Target Value 220010 - Retained Surplus(Accum Losses)
# Lookup Vlaue 220060 - Admin Restructure - OUT - PPE - PTE Target Value 220060 - Admin Restructure - OUT - PPE - PTE
# Lookup Vlaue 221050 - Admin Restructure - IN - Receivables Government Target Value 221050 - Admin Restructure - IN - Receivables Government
# Lookup Vlaue 221110 - Admin Restructure - Borrowings Target Value 221110 - Admin Restructure - Borrowings
# Lookup Vlaue 220010_C - Calculated Retained Earnings Target Value 220010_C - Calculated Retained Earnings
# Lookup Vlaue 220015 - Retained Surplus/(Accum Losses) Manual Posting Target Value 220015 - Retained Surplus/(Accum Losses) Manual Posting
# Lookup Vlaue 220045 - Accumulated funds - transfers from reserves Target Value 220045 - Accumulated funds - transfers from reserves
# Lookup Vlaue 220065 - Admin Restructure - OUT - PPE - GG Target Value 220065 - Admin Restructure - OUT - PPE - GG
# Lookup Vlaue 221095 - Admin Restructure - IN - Other Provisions Target Value 221095 - Admin Restructure - IN - Other Provisions
# Lookup Vlaue 999999_C - Calculated Intercompany Balancing Plug Target Value 999999_C - Calculated Intercompany Balancing Plug
# Lookup Vlaue 221115 - Admin Restructure - IN - Other liabilities Target Value 221115 - Admin Restructure - IN - Other liabilities
# Lookup Vlaue 221040 - Admin Restructure-IN-Other assets Target Value 221040 - Admin Restructure-IN-Other assets
# Lookup Vlaue 221035 - Admin Restructure - IN - PPE  - GG Target Value 221035 - Admin Restructure - IN - PPE  - GG
# Lookup Vlaue 220018 - Accumulated funds- changes in accounting policy Target Value 220018 - Accumulated funds- changes in accounting policy
# Lookup Vlaue H2_240000 - Reserves Target Value H2_240000 - Reserves
# Lookup Vlaue H2_210000 - Asset revaluation surplus Target Value H2_210000 - Asset revaluation surplus
# Lookup Vlaue 211020 - Asset Reval Reserve - Land Target Value 211020 - Asset Reval Reserve - Land
# Lookup Vlaue 211040 - Asset Reval Reserve - Plant & Equipment Target Value 211040 - Asset Reval Reserve - Plant & Equipment
# Lookup Vlaue 211060 - Asset Reval Reserve - Road Infrastructure Target Value 211060 - Asset Reval Reserve - Road Infrastructure
# Lookup Vlaue 211070 - Asset Reval Reserve - Maritime Infrastructure Target Value 211070 - Asset Reval Reserve - Maritime Infrastructure
# Lookup Vlaue 211090 - Asset Reval Reserve - Rolling Stock Target Value 211090 - Asset Reval Reserve - Rolling Stock
# Lookup Vlaue 211100 - Asset Reval Reserve - Ferries Target Value 211100 - Asset Reval Reserve - Ferries
# Lookup Vlaue 211110 - Asset Reval Reserve - Buses Target Value 211110 - Asset Reval Reserve - Buses
# Lookup Vlaue 211030 - Asset Reval Reserve - Buildings Target Value 211030 - Asset Reval Reserve - Buildings
# Lookup Vlaue 211050 - Asset Reval Reserve - Rail Infrastructure Target Value 211050 - Asset Reval Reserve - Rail Infrastructure
# Lookup Vlaue 211021 - Asset Reval Reserve - Admin Land Target Value 211021 - Asset Reval Reserve - Admin Land
# Lookup Vlaue 211023 - Asset Reval Reserve - Land Under Roads Target Value 211023 - Asset Reval Reserve - Land Under Roads
# Lookup Vlaue 211063 - Asset Reval Reserve - Traffic Control Infrastr Target Value 211063 - Asset Reval Reserve - Traffic Control Infrastr
# Lookup Vlaue 211064 - Asset Reval Reserve - Traffic Signal Infrastr Target Value 211064 - Asset Reval Reserve - Traffic Signal Infrastr
# Lookup Vlaue 211066 - Asset Reval Reserve - Bridges Target Value 211066 - Asset Reval Reserve - Bridges
# Lookup Vlaue 211121 - Asset Reval Reserve - LAFFRW Target Value 211121 - Asset Reval Reserve - LAFFRW
# Lookup Vlaue 211170 - Asset reval reserve - service concession infrast Target Value 211170 - Asset reval reserve - service concession infrast
# Lookup Vlaue 211180 - Asset reval resrve-service concession infra Rail Target Value 211180 - Asset reval resrve-service concession infra Rail
# Lookup Vlaue 211185 - Asset reval reserve - service concession Land Target Value 211185 - Asset reval reserve - service concession Land
# Lookup Vlaue 211190 - Asset reval reserve - service conce Rolling Stock Target Value 211190 - Asset reval reserve - service conce Rolling Stock
# Lookup Vlaue 211024 - Asset Revaluation Reserve - Land under Track Target Value 211024 - Asset Revaluation Reserve - Land under Track
# Lookup Vlaue 211175 - Asset reval reserve-service concesion infr Bridges Target Value 211175 - Asset reval reserve-service concesion infr Bridges
# Lookup Vlaue 211195 - Asset reval resve-serv conces infr Traffic Control Target Value 211195 - Asset reval resve-serv conces infr Traffic Control
# Lookup Vlaue 211032 - Asset reval reserve-service conces building &Impro Target Value 211032 - Asset reval reserve-service conces building &Impro
# Lookup Vlaue 211033 - Asset reval res-serv conc building toll road Target Value 211033 - Asset reval res-serv conc building toll road
# Lookup Vlaue 112665 - Post Paid E-Toll Tag Debtors Target Value 112665 - Post Paid E-Toll Tag Debtors
# Lookup Vlaue 112605 - Opal Payment Clearing Target Value 112605 - Opal Payment Clearing
# Lookup Vlaue 112680 - Intercoagency Receivable Target Value 112680 - Intercoagency Receivable
# Lookup Vlaue 112670 - ETS Operator Receivables Target Value 112670 - ETS Operator Receivables
# Lookup Vlaue 112675 - SNSW - Receivables Clearing Target Value 112675 - SNSW - Receivables Clearing
# Lookup Vlaue 112600 - Other Receivables Target Value 112600 - Other Receivables
# Lookup Vlaue H2_112455 - Property sales Target Value H2_112455 - Property sales
# Lookup Vlaue 112045 - Property Sale Proceeds Clearing Target Value 112045 - Property Sale Proceeds Clearing
# Lookup Vlaue 112070 - Property Receipts Clearing Target Value 112070 - Property Receipts Clearing
# Lookup Vlaue H2_112450 - Investment income receivable Target Value H2_112450 - Investment income receivable
# Lookup Vlaue 112350 - Accrued Income - Interest Receivable Target Value 112350 - Accrued Income - Interest Receivable
# Lookup Vlaue H2_112800 - Allowance for expected credit loss Target Value H2_112800 - Allowance for expected credit loss
# Lookup Vlaue 112710 - Allowance for Impairment - Other Receivables Target Value 112710 - Allowance for Impairment - Other Receivables
# Lookup Vlaue 112720 - SHBEToll Provision for Doubtful Debt Target Value 112720 - SHBEToll Provision for Doubtful Debt
# Lookup Vlaue 112800 - Allowance for expected credit loss Target Value 112800 - Allowance for expected credit loss
# Lookup Vlaue H2_113000 - Inventories Target Value H2_113000 - Inventories
# Lookup Vlaue H2_113100 - Materials, spare parts and other stores Target Value H2_113100 - Materials, spare parts and other stores
# Lookup Vlaue 113000 - Inventory on Hand Target Value 113000 - Inventory on Hand
# Lookup Vlaue H2_114000 - Derivative assets Target Value H2_114000 - Derivative assets
# Lookup Vlaue H2_114100 - Financial assets held for trading Target Value H2_114100 - Financial assets held for trading
# Lookup Vlaue H2_114110 - Derivatives Target Value H2_114110 - Derivatives
# Lookup Vlaue H2_114111 - Foreign exchange derivatives - cash flow hedges Target Value H2_114111 - Foreign exchange derivatives - cash flow hedges
# Lookup Vlaue 114200 - FX Hedge Asset Target Value 114200 - FX Hedge Asset
# Lookup Vlaue H2_114113 - Derivatives - Interest rate swaps Target Value H2_114113 - Derivatives - Interest rate swaps
# Lookup Vlaue 114220 - Derivate asset-Interest rate swap (Current) Target Value 114220 - Derivate asset-Interest rate swap (Current)
# Lookup Vlaue H2_114200 - Financial assets at fair value through profit or loss Target Value H2_114200 - Financial assets at fair value through profit or loss
# Lookup Vlaue H2_114210 - Tcorp Hour-Glass investment facilities Target Value H2_114210 - Tcorp Hour-Glass investment facilities
# Lookup Vlaue 114060 - TCorp HR Gl Investment Facility Target Value 114060 - TCorp HR Gl Investment Facility
# Lookup Vlaue H2_115000 - Non-current assets held for sale Target Value H2_115000 - Non-current assets held for sale
# Lookup Vlaue H2_115100 - Land and buildings held for sale Target Value H2_115100 - Land and buildings held for sale
# Lookup Vlaue 115000 - Asset Held for Sale - Land (Non-current) Target Value 115000 - Asset Held for Sale - Land (Non-current)
# Lookup Vlaue 115060 - Asset Held for Sale - Land & Buildings (Level 2) Target Value 115060 - Asset Held for Sale - Land & Buildings (Level 2)
# Lookup Vlaue H2_116000 - Other financial assets Target Value H2_116000 - Other financial assets
# Lookup Vlaue H2_116300 - Biodiversity total fund deposit Target Value H2_116300 - Biodiversity total fund deposit
# Lookup Vlaue 114920 - Biodiversity - Total Fund Deposit (TFD) Target Value 114920 - Biodiversity - Total Fund Deposit (TFD)
# Lookup Vlaue H2_120000 - Total non-current assets Target Value H2_120000 - Total non-current assets
# Lookup Vlaue H2_121000 - Receivables Target Value H2_121000 - Receivables
# Lookup Vlaue H2_121200 - Other receivables Target Value H2_121200 - Other receivables
# Lookup Vlaue 121210 - Receivables (Non-current) Target Value 121210 - Receivables (Non-current)
# Lookup Vlaue H2_121300 - Prepayments Target Value H2_121300 - Prepayments
# Lookup Vlaue 121420 - Prepayment  - Contractors (Non-current) Target Value 121420 - Prepayment  - Contractors (Non-current)
# Lookup Vlaue 121430 - Prepayments - Noncurrent Target Value 121430 - Prepayments - Noncurrent
# Lookup Vlaue H2_123000 - Derivative assets Target Value H2_123000 - Derivative assets
# Lookup Vlaue H2_123100 - Financial assets held for trading Target Value H2_123100 - Financial assets held for trading
# Lookup Vlaue H2_123110 - Derivatives Target Value H2_123110 - Derivatives
# Lookup Vlaue H2_123111 - Foreign exchange derivatives - cash flow hedges Target Value H2_123111 - Foreign exchange derivatives - cash flow hedges
# Lookup Vlaue 124000 - FX Hedge Asset (Non-current) Target Value 124000 - FX Hedge Asset (Non-current)
# Lookup Vlaue H2_123113 - Derivatives - Interest rate swaps Target Value H2_123113 - Derivatives - Interest rate swaps
# Lookup Vlaue 123220 - Derivate asset-Interest rate swap (Non-current) Target Value 123220 - Derivate asset-Interest rate swap (Non-current)
# Lookup Vlaue H2_124000 - Other financial assets Target Value H2_124000 - Other financial assets
# Lookup Vlaue H2_124300 - Promissory notes Target Value H2_124300 - Promissory notes
# Lookup Vlaue 124020 - Promissory Notes Eastern Distributor (Non-current) Target Value 124020 - Promissory Notes Eastern Distributor (Non-current)
# Lookup Vlaue 124025 - Promissory Notes M2 Motorway (Non-current) Target Value 124025 - Promissory Notes M2 Motorway (Non-current)
# Lookup Vlaue H2_124100 - Interest free advances to taxi operators Target Value H2_124100 - Interest free advances to taxi operators
# Lookup Vlaue 121205 - Other Loans Receivable (Non-current) Target Value 121205 - Other Loans Receivable (Non-current)
# Lookup Vlaue H2_124500 - Loan to Transport Asset Holding Entity of New South Wales Target Value H2_124500 - Loan to Transport Asset Holding Entity of New South Wales
# Lookup Vlaue 124030 - Loan to TAHE- Non Current Target Value 124030 - Loan to TAHE- Non Current
# Lookup Vlaue H2_125000 - Property, plant and equipment Target Value H2_125000 - Property, plant and equipment
# Lookup Vlaue H2_125500 - Land and buildings Target Value H2_125500 - Land and buildings
# Lookup Vlaue H2_125510 - Land and buildings Target Value H2_125510 - Land and buildings
# Lookup Vlaue H2_125570 - Land - Gross carrying value (at fair value) Target Value H2_125570 - Land - Gross carrying value (at fair value)
# Lookup Vlaue 125000 - Land (Level 3) Target Value 125000 - Land (Level 3)
# Lookup Vlaue 125009 - Service Concession Assets Land Target Value 125009 - Service Concession Assets Land
# Lookup Vlaue H2_125580 - Building - Gross carrying value (at fair value) Target Value H2_125580 - Building - Gross carrying value (at fair value)
# Lookup Vlaue 125050 - Buildings (Level 3) Target Value 125050 - Buildings (Level 3)
# Lookup Vlaue 125055 - Buildings (Level 3) NonFAR Target Value 125055 - Buildings (Level 3) NonFAR
# Lookup Vlaue 125086 - Service Concession Assets Building & Improvements Target Value 125086 - Service Concession Assets Building & Improvements
# Lookup Vlaue 125084 - Building-NON FAR (Notional) Target Value 125084 - Building-NON FAR (Notional)
# Lookup Vlaue 125090 - Serv Conc Asst Gross Cost BuildingTollRoad NON FAR Target Value 125090 - Serv Conc Asst Gross Cost BuildingTollRoad NON FAR
# Lookup Vlaue H2_125558 - Land and buildings acquired for future roadworks Target Value H2_125558 - Land and buildings acquired for future roadworks
# Lookup Vlaue H2_125559 - Surplus properties Target Value H2_125559 - Surplus properties
# Lookup Vlaue 125002 - Land - Residue (Level 2) Target Value 125002 - Land - Residue (Level 2)
# Lookup Vlaue H2_125582 - Rentable properties Target Value H2_125582 - Rentable properties
# Lookup Vlaue 125003 - Land - Rented (Level 2) Target Value 125003 - Land - Rented (Level 2)
# Lookup Vlaue H2_125583 - Untenanted Land for Roads Target Value H2_125583 - Untenanted Land for Roads
# Lookup Vlaue 125004 - Land - Public Reserve (Level 2) Target Value 125004 - Land - Public Reserve (Level 2)
# Lookup Vlaue 125006 - Untenanted Land for Road (Level 2) Target Value 125006 - Untenanted Land for Road (Level 2)
# Lookup Vlaue H2_125555 - Leasehold improvements Target Value H2_125555 - Leasehold improvements
# Lookup Vlaue H2_125556 - Gross carrying value (at fair value) Target Value H2_125556 - Gross carrying value (at fair value)
# Lookup Vlaue 125060 - Leasehold Improvements (Level 3) Target Value 125060 - Leasehold Improvements (Level 3)
# Lookup Vlaue 125065 - Leasehold Improvements (Level 3)NonFAR Target Value 125065 - Leasehold Improvements (Level 3)NonFAR
# Lookup Vlaue H2_125560 - Assets under construction - Land and buildings Target Value H2_125560 - Assets under construction - Land and buildings
# Lookup Vlaue H2_125562 - Gross carrying value (at fair value) Target Value H2_125562 - Gross carrying value (at fair value)
# Lookup Vlaue 125700 - Asset under Construction - Land (Level 3 Target Value 125700 - Asset under Construction - Land (Level 3
# Lookup Vlaue 125705 - Asset under Construction - Buildings (Le Target Value 125705 - Asset under Construction - Buildings (Le
# Lookup Vlaue 125706 - Asset under Construction-Buildings(Level 3)NonFAR Target Value 125706 - Asset under Construction-Buildings(Level 3)NonFAR
# Lookup Vlaue H2_125554 - Accumulated depreciation and impairment (at fair value) Target Value H2_125554 - Accumulated depreciation and impairment (at fair value)
# Lookup Vlaue 125051 - Accumulated Depreciation - Buildings (Level 3) Target Value 125051 - Accumulated Depreciation - Buildings (Level 3)
# Lookup Vlaue 125056 - Accumulated Depreciation - Buildings (Level 2) Target Value 125056 - Accumulated Depreciation - Buildings (Level 2)
# Lookup Vlaue 125085 - Accum. Depreciation - Buildings NON FAR (Notional) Target Value 125085 - Accum. Depreciation - Buildings NON FAR (Notional)
# Lookup Vlaue 125087 - Service Conce AsseBuilding&ImproveAccuDeprn Target Value 125087 - Service Conce AsseBuilding&ImproveAccuDeprn
# Lookup Vlaue 125091 - Serv Conce Asst Acc Dep Building Toll Road NON FAR Target Value 125091 - Serv Conce Asst Acc Dep Building Toll Road NON FAR
# Lookup Vlaue H2_125588 - Accumulated depreciation and impairment (at fair value) - Leasehold improvements Target Value H2_125588 - Accumulated depreciation and impairment (at fair value) - Leasehold improvements
# Lookup Vlaue 125061 - Accumulated Amortistation-Leasehold ImprovementsL3 Target Value 125061 - Accumulated Amortistation-Leasehold ImprovementsL3
# Lookup Vlaue H2_125700 - Plant and equipment Target Value H2_125700 - Plant and equipment
# Lookup Vlaue H2_125710 - Plant and equipment Target Value H2_125710 - Plant and equipment
# Lookup Vlaue H2_125712 - Gross carrying value (at fair value) Target Value H2_125712 - Gross carrying value (at fair value)
# Lookup Vlaue 125100 - Plant and Equipment Target Value 125100 - Plant and Equipment
# Lookup Vlaue 125150 - Motor Vehicles Target Value 125150 - Motor Vehicles
# Lookup Vlaue 125132 - Plant & Equipment- Non FAR (Notional) Target Value 125132 - Plant & Equipment- Non FAR (Notional)
# Lookup Vlaue 125170 - Service Concession Assets Plant & EquipmentNON FAR Target Value 125170 - Service Concession Assets Plant & EquipmentNON FAR
# Lookup Vlaue 125172 - Serv Conc Asst Gross CostEquipmentTollRoad NON FAR Target Value 125172 - Serv Conc Asst Gross CostEquipmentTollRoad NON FAR
# Lookup Vlaue 125177 - SCA Plant & Equipment Target Value 125177 - SCA Plant & Equipment
# Lookup Vlaue H2_125714 - Accumulated depreciation and impairment (at fair value) Target Value H2_125714 - Accumulated depreciation and impairment (at fair value)
# Lookup Vlaue 125101 - Accumulated Depreciation - Plant & Equipment Target Value 125101 - Accumulated Depreciation - Plant & Equipment
# Lookup Vlaue 125151 - Accumulated Depreciation - Motor Vehicles Target Value 125151 - Accumulated Depreciation - Motor Vehicles
# Lookup Vlaue 125133 - Accum. Depreciation -P&E NON FAR (Notional) Target Value 125133 - Accum. Depreciation -P&E NON FAR (Notional)
# Lookup Vlaue 125171 - Service Conce Assets Plant&Equp Accu Deprn NON FAR Target Value 125171 - Service Conce Assets Plant&Equp Accu Deprn NON FAR
# Lookup Vlaue 125173 - Serv Conc Asst Acc Dep Equipment Toll Road NON FAR Target Value 125173 - Serv Conc Asst Acc Dep Equipment Toll Road NON FAR
# Lookup Vlaue 125176 - SCA Plant & Equip Accum Depn Target Value 125176 - SCA Plant & Equip Accum Depn
# Lookup Vlaue H2_125715 - Asset under construction - Plant & Equipment Target Value H2_125715 - Asset under construction - Plant & Equipment
# Lookup Vlaue 125710 - Asset under Construction - Plant & Equip Target Value 125710 - Asset under Construction - Plant & Equip
# Lookup Vlaue 125712 - AUC-Plant & Equipment Non Control Target Value 125712 - AUC-Plant & Equipment Non Control
# Lookup Vlaue H2_125730 - Rolling stock  Target Value H2_125730 - Rolling stock
# Lookup Vlaue H2_125732 - Gross carrying value (at fair value) Target Value H2_125732 - Gross carrying value (at fair value)
# Lookup Vlaue 125300 - Rolling Stock Target Value 125300 - Rolling Stock
# Lookup Vlaue 125754 - SCA-Rolling stock Target Value 125754 - SCA-Rolling stock
# Lookup Vlaue H2_125734 - Accumulated depreciation and impairment (at fair value) Target Value H2_125734 - Accumulated depreciation and impairment (at fair value)
# Lookup Vlaue 125301 - Accumulated Depreciation - Rolling Stock Target Value 125301 - Accumulated Depreciation - Rolling Stock
# Lookup Vlaue 125756 - SCA-Rolling stock accumulated depreciation Target Value 125756 - SCA-Rolling stock accumulated depreciation
# Lookup Vlaue H2_125716 - Asset under Construction - Rolling Stock Target Value H2_125716 - Asset under Construction - Rolling Stock
# Lookup Vlaue 125735 - Asset under Construction - Rolling Stock Target Value 125735 - Asset under Construction - Rolling Stock
# Lookup Vlaue 125739 - AUC - SCA Rolling Stock NON FAR Target Value 125739 - AUC - SCA Rolling Stock NON FAR
# Lookup Vlaue 125734 - AUC - Rolling Stock NON FAR Target Value 125734 - AUC - Rolling Stock NON FAR
# Lookup Vlaue H2_125740 - Buses Target Value H2_125740 - Buses
# Lookup Vlaue H2_125749 - Buses (excl. AUC) Target Value H2_125749 - Buses (excl. AUC)
# Lookup Vlaue H2_125742 - Gross carrying value (at fair value) Target Value H2_125742 - Gross carrying value (at fair value)
# Lookup Vlaue 125200 - Buses Target Value 125200 - Buses
# Lookup Vlaue 125202 - Buses - Owned  -non-control account Target Value 125202 - Buses - Owned  -non-control account
# Lookup Vlaue H2_125745 - Asset under construction- buses Target Value H2_125745 - Asset under construction- buses
# Lookup Vlaue 125725 - Asset under Construction - Buses Target Value 125725 - Asset under Construction - Buses
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-6261c51a77f7> in <cell line: 32>()
#      35           lookup_value = cell.value
#      36           column_heading = ws.cell(row=1, column=cell.col_idx) #To-do
# ---> 37           for row_trgt_index, row_trgt in enumerate(CAR_sheet.iter_rows(min_row=min_row, min_col = 3), start=1): #This loops on rows of Target sheet
#      38             if value_found == 'X':
#      39               break
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/worksheet.py in iter_rows(self, min_row, max_row, min_col, max_col, values_only)
#     441         min_col = min_col or 1
#     442         min_row = min_row or 1
# --> 443         max_col = max_col or self.max_column
#     444         max_row = max_row or self.max_row
#     445
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/worksheet.py in max_column(self)
#     376         max_col = 1
#     377         if self._cells:
# --> 378             cols = set(c[1] for c in self._cells)
#     379             max_col = max(cols)
#     380         return max_col
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/worksheet.py in <genexpr>(.0)
#     376         max_col = 1
#     377         if self._cells:
# --> 378             cols = set(c[1] for c in self._cells)
#     379             max_col = max(cols)
#     380         return max_col
#
# KeyboardInterrupt:

# %%
#**************************************************************************************This is a version that retains the formulas**************************************************************************
from numpy.core.multiarray import concatenate
import pandas as pd
import openpyxl
import numpy as np
import re
from openpyxl.styles import PatternFill, Border, Side, Alignment, Protection, Font

wb = openpyxl.load_workbook('/content/DoT (Cluster) AR.xlsx', data_only=False, rich_text=True)
indx_sheet = wb['Index']
add_col_idx = indx_sheet.max_column + 1
#sheet_names = wb.sheetnames
# Use the following SWITCH to define "scope" of the script. False = Do not apply, True = Apply
Font_Size_Switch = True
Row_Height_Switch = True
Border_Switch = True # False will not remove vertical borders
Column_Width_Switch = True
#print(wb.sheetnames)#
for title in wb.sheetnames:
  print("Start of", title)
  ws = wb[title]
#  hidden_flg = ws.sheet_state
  for name_range in wb.defined_names.values():
   char_idx = name_range.attr_text.find('!')
   #print(ws.sheet_state)
   if ws.title==name_range.attr_text[:char_idx] and ws.sheet_state == 'visible':
    #named_array = wb.defined_names[title]
    #print("I am processing",ws.title)
    cell_range=name_range.attr_text
    #print(cell_range)
    start_cell, end_cell = cell_range.split(':')
    sheet, start_cell = start_cell.split('!')
    start_cell = start_cell.replace("$","")
    end_cell = end_cell.replace("$","")
    start_row, start_col = openpyxl.utils.cell.coordinate_to_tuple(start_cell)
    end_row, end_col= openpyxl.utils.cell.coordinate_to_tuple(end_cell)
    row_height = 14.5
    index = 0
    num_count = 0
    cnt_nts = 0
    hidden_columns = []
    notes_exists = False
    min=0
    max=0
    h_min=0
    h_max=0
    true_end = end_col
    hiddenList=[]
    groupedList=[]

    #Thi block loops on rows defined in the named range to find Notes colum
    for row in ws.iter_rows():
        for row_cell in row:
         if row_cell.value =="Notes" or row_cell.value =="Note":
          notes_exists=True
          cnt_nts = row_cell.col_idx
          print("Notes Index position",cnt_nts)
          break
    # This block determines number of numeric columns

    for col_h in range(start_col , end_col + 1):
        sheet_cell = ws.cell(row=end_row, column=col_h)
        #print("sheet scope", sheet_cell.value, col_h, bool )
        #print(col_h, ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min, ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max, ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].hidden, ws.title )
        if col_h in groupedList: #col_h == true_end and not ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min:
          ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min = col_h
          ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max = col_h
          num_count += 1
          print("I am columns", col_h,"I am in condition 0")
          continue
        if col_h in hiddenList: #min and max and col_h > min and col_h <= max and not ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].hidden :
             print("I am column", col_h, "and I am in condition 1")
             continue
        elif not ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].hidden and ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min == ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max: #This is a default scenario for visible columns
             #print(type(sheet_cell.value))
             if (re.match(r'^#',last_row_values.number_format)) and col_h != cnt_nts: # isinstance(sheet_cell.value, (int, float)): #
                  num_count += 1
                  print("I am column", col_h, "and I am in condition 2")
        elif ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].hidden and ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min != ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max:   #This capture the first cell of hidden cell range
              hiddenList.clear()
              for i in range(ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min, ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max + 1):
                            hiddenList.append(i)
              h_min = ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min
              h_max = ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max
              print("I am column", col_h, "and I am in condition 3", hiddenList )
              continue
        elif not ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].hidden and ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min != ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max:   #This captures any grouped columns that have min & max defined None and are visible in excel
              groupedList.clear()
              for i in range(ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min, ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max + 1):
                            groupedList.append(i)
              min = ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min
              max = ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max
              num_count += 1
              print("I am column", col_h, "and I am in condition 4",min,max, groupedList)

    print("Numeric columns", num_count, ws.title)


    #Loop on rows defined in the named range
    for row in range(start_row, end_row + 1):
      index += 1
      if Row_Height_Switch is True:
        #set the row height to 14.5
        ws.row_dimensions[row].height=row_height
        Is_hidden = ws.row_dimensions[row].hidden
      groupedList.clear()
      hiddenList.clear()
      col_index=start_col + 1
# Loop on columns starting from the range defined in Named Range
      for col in range(start_col , end_col + 1):
       sheet_cell = ws.cell(row=row, column=col)
       if index==1: #Row 1
        last_row_values = ws.cell(row=end_row, column=col)
#******This block is to hide columns that come as visible due to excel functionality to Group columns that are hidden consecutively hidden********
        if col in groupedList: #col_h == true_end and not ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min:
          fstyle_bold = sheet_cell.font.bold
          fstyle_italic = sheet_cell.font.italic
        if col_h in hiddenList: #min and max and col_h > min and col_h <= max and not ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].hidden :
          ws.column_dimensions[openpyxl.utils.get_column_letter(col)].hidden = True
          continue
        elif not ws.column_dimensions[openpyxl.utils.get_column_letter(col)].hidden and ws.column_dimensions[openpyxl.utils.get_column_letter(col)].min == ws.column_dimensions[openpyxl.utils.get_column_letter(col)].max: #This is a default scenario for visible columns
          fstyle_bold = sheet_cell.font.bold
          fstyle_italic = sheet_cell.font.italic
        elif ws.column_dimensions[openpyxl.utils.get_column_letter(col)].hidden and ws.column_dimensions[openpyxl.utils.get_column_letter(col)].min != ws.column_dimensions[openpyxl.utils.get_column_letter(col)].max:   #This capture the first cell of hidden cell range
          hiddenList.clear()
          for i in range(ws.column_dimensions[openpyxl.utils.get_column_letter(col)].min, ws.column_dimensions[openpyxl.utils.get_column_letter(col)].max + 1):
                            hiddenList.append(i)
          print("I am column", col_h, "and I am in condition 3", hiddenList )
          continue
        elif not ws.column_dimensions[openpyxl.utils.get_column_letter(col)].hidden and ws.column_dimensions[openpyxl.utils.get_column_letter(col)].min != ws.column_dimensions[openpyxl.utils.get_column_letter(col)].max:   #This captures any grouped columns that have min & max defined None and are visible in excel
          groupedList.clear()
          for i in range(ws.column_dimensions[openpyxl.utils.get_column_letter(col)].min, ws.column_dimensions[openpyxl.utils.get_column_letter(col)].max + 1):
                            groupedList.append(i)
          fstyle_bold = sheet_cell.font.bold
          fstyle_italic = sheet_cell.font.italic
          print("I am column", col_h, "and I am in condition 4",min,max, groupedList)
#********End of block*************

        if not Font_Size_Switch:
            font_size = sheet_cell.font.size
        else:
            # Set the font SIZE based on numeric columns
            if num_count <= 8:
              font_size = 9
            elif num_count in (9, 10):
              font_size = 8
            else:
              font_size = 7

 #******This block sets the Column Width at row of the defined range as this block is executed within Index 1 if condition above
        if Column_Width_Switch is True:
          if notes_exists and col==col_index:
              if num_count == 1:
                   col_width = 8.91
              elif num_count == 2:
                   col_width = 8.91
              elif num_count==3:
                   col_width = 8.91
              elif num_count==4:
                   col_width=8.18
              elif num_count==5:
                   col_width=7.82
              elif num_count==6:
                   col_width=8.91
              elif num_count==7:
                   col_width=8.55
              elif num_count==8:
                   col_width=8.18
              elif num_count==9:
                   col_width=7.82
              elif num_count==10:
                   col_width=7
              elif num_count==11:
                   col_width=6.18
              else:
                   col_width=6.18
              print("I am using", col_width, "for Notes columns in sheet", ws.title)
                # now update the worksheet with above column widths
              ws.column_dimensions[openpyxl.utils.get_column_letter(col)].width=col_width
          if col==start_col and not notes_exists: #This is for column 1
                #Set the default column WIDTH of first colum based on how many numeric columns
                if num_count == 1:
                    col_width = 65.55 + 8.91
                elif num_count == 2:
                    col_width = 53.55 + 8.91
                elif num_count==3:
                    col_width = 41.45 + 8.91
                elif num_count==4:
                    col_width=34.18 + 8.18
                elif num_count==5:
                    col_width=26.09 + 7.82
                elif num_count==6:
                    col_width=49 + 8.91
                elif num_count==7:
                    col_width=40.82 + 8.55
                elif num_count==8:
                    col_width=33.64 + 8.18
                elif num_count==9:
                    col_width=27.55 + 7.82
                elif num_count==10:
                    col_width=27.91 + 7
                elif num_count==11:
                    col_width=61.4 + 6.18
                else:
                    col_width=21.64 + 6.18
                ws.column_dimensions[openpyxl.utils.get_column_letter(col)].width=col_width
                # set the column widths in worksheet
                print(col, col_width, "for label")
          if col==start_col and notes_exists: #This is for column 1
                #Set the default column WIDTH of first colum based on how many numeric columns
                if num_count == 1:
                    col_width = 65.55
                elif num_count == 2:
                    col_width = 53.55
                elif num_count==3:
                    col_width = 41.45
                elif num_count==4:
                    col_width=34.18
                elif num_count==5:
                    col_width=26.09
                elif num_count==6:
                    col_width=49
                elif num_count==7:
                    col_width=40.82
                elif num_count==8:
                    col_width=33.64
                elif num_count==9:
                    col_width=27.55
                elif num_count==10:
                    col_width=27.91
                elif num_count==11:
                    col_width=61.4
                else:
                    col_width=21.64
                # set the column widths in worksheet
                print(col, col_width, "for label")
                ws.column_dimensions[openpyxl.utils.get_column_letter(col)].width=col_width
                print(ws.column_dimensions[openpyxl.utils.get_column_letter(col)].width)
          if (re.match(r'^#',last_row_values.number_format)) and col!=cnt_nts: #isinstance(last_row_values, (int, float)): #
                #Set the default column WIDTH for numeric column based on how many amount columns are in sheet
                if num_count <= 3 or num_count==6:
                   col_width = 11.45
                elif num_count == 4:
                   col_width = 10.36
                elif num_count==5:
                   col_width = 9.91
                elif num_count==7:
                   col_width=10.91
                elif num_count==8:
                   col_width=10.36
                elif num_count==9:
                   col_width=9.64
                elif num_count==10:
                   col_width=8.82
                else:
                   col_width=7.91
                print("I am using", col_width, "for amount")
                # set the column widths in worksheet
                ws.column_dimensions[openpyxl.utils.get_column_letter(col)].width=col_width
        elif not Column_Width_Switch:
          ws.column_dimensions[openpyxl.utils.get_column_letter(col)].width=ws.column_dimensions[openpyxl.utils.get_column_letter(col)].width
#********This block sets the font size and formatting properties of cell***************
       font_prpts = {}
       if Font_Size_Switch and index == 1:
         #set the font properties for row 1
         fstyle_bold = sheet_cell.font.bold
         fstyle_italic = sheet_cell.font.italic
         fstyle_size = sheet_cell.font.size
         #print("I am setting", fstyle_bold, "font properties of", row, col)
         font_prpts= { "name": "Arial",
              "size": fstyle_size,
              "bold": fstyle_bold,
              "italic": fstyle_italic,
              "vertAlign":"baseline",
              "underline":"none",
              "strike":False }
         font = Font(**font_prpts)
         sheet_cell.font = font
       elif Font_Size_Switch and index != 1:
         fstyle_bold = sheet_cell.font.bold
         fstyle_italic = sheet_cell.font.italic
         fstyle_size = sheet_cell.font.size
         #print("I am setting", fstyle_bold, "font properties of", row, col)
        #set the font properties for remaining rows
         font_prpts= { "name": "Arial",
              "size": fstyle_size if not Font_Size_Switch else 9.0,
              "bold": fstyle_bold,
              "italic": fstyle_italic,
              "vertAlign":"baseline",
              "underline":"none",
              "strike":False }
       font = Font(**font_prpts)
       sheet_cell.font = font
#*********This block sets the formatting properties*****************#
       if Border_Switch == True and not 'PPE' in ws.title:
          if sheet_cell.border.left.border_style == "thin" or sheet_cell.border.right.border_style == "thin":
             sheet_cell.border.left.border_style = 'none'
             sheet_cell.border.right.border_style = 'none'
             print("a border is removed at cell location", col, ws.title)
       if row == start_row and sheet_cell.value=="Notes" or sheet_cell.value=="Note":
             sheet_cell.alignment = Alignment(horizontal='right',
                                              vertical = 'bottom',
                                              wrap_text=True)
       elif row == start_row and sheet_cell.value!="Notes" or sheet_cell.value=="Note":
               sheet_cell.alignment = Alignment(horizontal='right',
                                                vertical = 'bottom',
                                                wrap_text=True)
       elif row != start_row and col == start_col:
             cell_index = sheet_cell.alignment.indent
             sheet_cell.alignment = Alignment(horizontal='left',
                                                vertical = 'bottom',
                                                wrap_text=True,
                                                indent=cell_index)
       elif col==col_index and notes_exists:
               sheet_cell.alignment = Alignment(horizontal='right',
                                                vertical = 'bottom',
                                                wrap_text=True)
               sheet_cell.number_format = 'General'

       else:
               sheet_cell.alignment = Alignment(horizontal='right',
                                                vertical = 'bottom',
                                                wrap_text=False)

  for irow in indx_sheet.iter_rows(min_row=2, max_row=indx_sheet.max_row, min_col=1, max_col=indx_sheet.max_column):
    for icell in irow:
      if icell.value==ws.title:
        indx_sheet.cell(row=icell.row, column=add_col_idx, value=num_count)

wb.save('test.xlsx')
