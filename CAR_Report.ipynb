# %% [markdown]
# <a href="https://colab.research.google.com/github/SSPYX/Colab/blob/main/CAR_Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy.core.multiarray import concatenate
import pandas as pd
import openpyxl
import numpy as np
import re
from openpyxl.styles import PatternFill, Border, Side, Alignment, Protection, Font

wb = openpyxl.load_workbook('/content/Copy of CAR Report DoT.xlsx', data_only=False, rich_text=True)
#sheet_names = wb.sheetnames
# Use the following SWITCH to define "scope" of the script. False = Do not apply, True = Apply
Font_Size_Switch = True
Row_Height_Switch = True
Border_Switch = False # False will not remove vertical borders
Column_Width_Switch = True
copy_switch = "N" # N means don't run the copy function, Y means run the copy function

for title in wb.sheetnames:
  ws = wb[title]
#  CAR_sheet = wb['CAR']

  for car_row_index, row_trgt in enumerate(ws.iter_rows(min_row=4, min_col = 3), start=1):
    value_found = None
    for cell in row_trgt:  #This loops on each column in a row in source worksheet
      if  cell.col_idx == 3 and  not value_found and re.match("H",cell.value):
          print(cell.value)
          value_found = 'X'
          fstyle_size = cell.font.size
          alignment = cell.alignment.indent
          border_style = Border(top=Side(border_style='thin'),
                                bottom=Side(border_style='thin'))
          #print("I am setting", fstyle_bold, "font properties of", row, col)
          font_prpts= { "name": "Arial",
                "size": fstyle_size,
                "bold": "bold",
                "vertAlign":"baseline",
                "underline":"none",
                "strike":False }
          font = Font(**font_prpts)
  #         cell.alignment.Alignment = alignment
          cell.border = border_style
          cell.font = font
          print(ws.cell(row=car_row_index, column=cell.col_idx).value)
      elif value_found:
          fstyle_size = cell.font.size
          alignment = cell.alignment.indent
          border_style = Border(top=Side(border_style='thin'),
                                bottom=Side(border_style='thin'))
          #print("I am setting", fstyle_bold, "font properties of", row, col)
          font_prpts= { "name": "Arial",
                "size": fstyle_size,
                "bold": "bold",
                "vertAlign":"baseline",
                "underline":"none",
                "strike":False }
          font = Font(**font_prpts)
  #         cell.alignment.Alignment = alignment
          cell.border = border_style
          cell.font = font
  wb.save('test.xlsx')
if copy_switch == "Y":
  match_row_idx = 0
  min_row = 4
  for heading_row in CAR_sheet.iter_rows(min_row=3, max_row=3):
    header_row = heading_row
    #print(header_row)
  for row_index, row in enumerate(ws.iter_rows(min_row=3, min_col = 3, max_col = 3), start=1): # This loops on row starting from 3 in source worksheet
    value_found = None
    for cell in row:  #This loops on each column in a row in source worksheet
            lookup_value = cell.value
            column_heading = ws.cell(row=1, column=cell.col_idx) #To-do
            for row_trgt_index, row_trgt in enumerate(CAR_sheet.iter_rows(min_row=min_row, min_col = 3, max_col = 3), start=1): #This loops on rows of Target sheet
              if value_found == 'X':
                break
              else:
                for col_trgt in row_trgt: #Loop over all columns in each row
                  if lookup_value==col_trgt.value:
                      print("Lookup Vlaue", lookup_value, "Target Value",  col_trgt.value)
      #              print(lookup_value)
                      value_found='X'
                      min_row = row_trgt_index + 1
                      break
#      elif cell.col_idx == 1:
#         continue
#      else:
#         break
# Out:
# H2_BS - Total Balance Sheet
# None
# H2_200000 - Total equity
# ECC Data
# H2_220000 - Accumulated funds
# 2024M6 - Dec 2023
# H2_240000 - Reserves
# 10834745.83
# H2_210000 - Asset revaluation surplus
# 15679320.69
# H2_230000 - Other reserves
# 2198
# H2_NA - Net assets
# -13358.73
# H2_100000 - Total assets
# 204572.9
# H2_110000 - Total current assets
# -4516
# H2_111000 - Cash and cash equivalents
# 2466933049.02
# H2_111001 - Operating account
# -81233854.49000001
# H2_111002 - Remitting account, cash in transit and cash on hand
# 1.83
# H2_111004 - Security deposits
# 1167073024.64
# H2_112000 - Total current trade and other receivables
# 27282121.759999998
# H2_112001 - Total receivables excluding impairment
# -2550
# H2_112100 - Sale of goods and services
# 4516
# H2_112150 - Retained taxes, fees and fines
# 1389224470.02
# H2_112300 - Prepayments
# 104739.73
# H2_112400 - Income receivable
# 5890878.529999999
# H2_112700 - Other receivables
# 13977245.02
# H2_112455 - Property sales
# 0
# H2_112450 - Investment income receivable
# 48460305
# H2_112600 - Personnel services receivable
# 38709908.93
# H2_112800 - Allowance for expected credit loss
# 10784.95
# H2_113000 - Inventories
# 742609285.05
# H2_113100 - Materials, spare parts and other stores
# 101400106.46000001
# H2_113300 - Provision for obsolescence
# 1921325.42
# H2_114000 - Derivative assets
# 639287853.17
# H2_114100 - Financial assets held for trading
# 178651949254.21002
# H2_114110 - Derivatives
# 5406158279.740001
# H2_114111 - Foreign exchange derivatives - cash flow hedges
# 5876165708.099999
# H2_114112 - Energy derivative - cash flow hedges
# 829991756.15
# H2_114113 - Derivatives - Interest rate swaps
# 995158411.8000001
# H2_114200 - Financial assets at fair value through profit or loss
# -0.08
# H2_114210 - Tcorp Hour-Glass investment facilities
# 160417512.17000002
# H2_115000 - Non-current assets held for sale
# 296148501.96
# H2_115100 - Land and buildings held for sale
# 3773248531.07
# H2_116000 - Other financial assets
# 1212588595.92
# H2_116300 - Biodiversity total fund deposit
# 1212588595.92
# H2_116400 - Energy Certificate - at cost
# 23611487.580000002
# H2_120000 - Total non-current assets
# 245757009.07999998
# H2_121000 - Receivables
# 245757009.07999998
# H2_121200 - Other receivables
# 236086248.73000002
# H2_121300 - Prepayments
# 32488993.839999996
# H2_122000 - Inventories
# -448211381.73999995
# H2_122100 - Materials, spare parts and other stores
# -292288158.51
# H2_123000 - Derivative assets
# 0.48
# H2_123100 - Financial assets held for trading
# -13694766.629999999
# H2_123110 - Derivatives
# -142228456.67000002
# H2_123111 - Foreign exchange derivatives - cash flow hedges
# -115863744.77
# H2_123112 - Energy derivative - cash flow hedges
# 774693111.51
# H2_123113 - Derivatives - Interest rate swaps
# 1513634606.1000001
# H2_124000 - Other financial assets
# -0.16
# H2_124300 - Promissory notes
# 0.53
# H2_124100 - Interest free advances to taxi operators
# -1103443827.92
# H2_124500 - Loan to Transport Asset Holding Entity of New South Wales
# -144144.91
# H2_125000 - Property, plant and equipment
# 1.84
# H2_125500 - Land and buildings
# -12070970.76
# H2_125510 - Land and buildings
# -8154212.52
# H2_125570 - Land - Gross carrying value (at fair value)
# 327449781.42
# H2_125580 - Building - Gross carrying value (at fair value)
# 50006282.52
# H2_125558 - Land and buildings acquired for future roadworks
# 35171914.01
# H2_125559 - Surplus properties
# 21600660.22
# H2_125582 - Rentable properties
# 329998683.72999996
# H2_125583 - Untenanted Land for Roads
# 1118902233.69
# H2_125555 - Leasehold improvements
# 73888727.5
# H2_125556 - Gross carrying value (at fair value)
# 81310493.11
# H2_125560 - Assets under construction - Land and buildings
# -862792277.5
# H2_125561 - Gross carrying amout (at cost)
# 0.04
# H2_125562 - Gross carrying value (at fair value)
# 45095667
# H2_125554 - Accumulated depreciation and impairment (at fair value)
# -21388561.330000002
# H2_125588 - Accumulated depreciation and impairment (at fair value) - Leasehold improvements
# 123627165428.73001
# H2_125700 - Plant and equipment
# 90477280468.78
# H2_125710 - Plant and equipment
# 9026977602.72
# H2_125712 - Gross carrying value (at fair value)
# 24122907357.23
# H2_125714 - Accumulated depreciation and impairment (at fair value)
# 27001303385.29
# H2_125715 - Asset under construction - Plant & Equipment
# -32657958015.64
# H2_125730 - Rolling stock
# -7405138600.469999
# H2_125732 - Gross carrying value (at fair value)
# -13757342804.49
# H2_125734 - Accumulated depreciation and impairment (at fair value)
# -1312404717.54
# H2_125716 - Asset under Construction - Rolling Stock
# -952928761.25
# H2_125740 - Buses
# -19330674803.97
# H2_125749 - Buses (excl. AUC)
# 37463195705.15
# H2_125742 - Gross carrying value (at fair value)
# 7252897067.92
# H2_125745 - Asset under construction- buses
# 32605346.6
# H2_125744 - Accumulated depreciation and impairment - Buses
# 264804326.93
# H2_125750 - Ferries
# 4760205544.92
# H2_125759 - Ferries (excl. AUC)
# -11270790.09
# H2_125752 - Gross carrying value (at fair value)
# 123661927.62
# H2_125754 - Accumulated depreciation and impairment (at fair value)
# -345849615.26
# H2_125755 - Asset under construction - Ferries
# 2377928593.21
# H2_125600 - Infrastructure systems
# -978313154.23
# H2_125610 - Road systems
# -978313154.23
# H2_125613 - Road Systems
# 150991943.26999998
# H2_125612 - Gross carrying value (at fair value)- Road
# 5110444.54
# H2_125680 - Gross carrying value (at fair value)- Land under roads and tracks
# 1685008022.84
# H2_125614 - Gross carrying value (at fair value)- Bridges and tunnels
# 58816432.620000005
# H2_125681 - Gross carrying value (at fair value)- Traffic signals network
# -21238296.41
# H2_125616 - Gross carrying value (at fair value)- Traffic controls network
# 0.15
# H2_125563 - Accumulated depreciation and impairment (Road Systems)
# 653493431.7700001
# H2_125617 - Accumulated depreciation- Roads
# 140527935.95
# H2_125619 - Accumulated depreciation- Bridges and tunnels
# 0.13
# H2_125645 - Accumulated depreciation- Traffic signals network
# 0.05
# H2_125646 - Accumulated depreciation- Traffic controls network
# 864554341.7
# H2_125615 - Asset under construction – Roads
# -2286548.32
# H2_125620 - Rail systems
# 0
# H2_125621 - Rail systems
# 14227246.02
# H2_125626 - Land under tracks
# 66187224.13
# H2_125623 - Gross carrying value (at fair value)
# 0
# H2_125642 - AUC - Gross carrying value (at fair value) - Rail
# 190557890.95000002
# H2_125644 -  Accumulated depreciation and impairment (at fair value)
# -25195974.83
# H2_125625 - Accumulated depreciation and impairment (at fair value)
# 1147352152.04
# H2_125630 - Maritime systems
# -463615238.88
# H2_125639 - Maritime Systems
# -235543395.75
# H2_125632 - Gross carrying value (at fair value)
# -77186580.97
# H2_125634 - Accumulated depreciation and impairment (at fair value)
# 46952734.629999995
# H2_125636 - Asset under construction – Maritime Infrastructure
# -5748513.58
# H2_127000 - Intangible assets
# 24112127227.57
# H2_127001 - Computer systems
# 4802085127.07
# H2_127100 - Computer systems - cost (gross carrying amount)
# 3054744493.4100003
# H2_127200 - Computer systems - accumulated amortisation and impairment
# -0.2
# H2_127002 - Right of use
# 1471266211.84
# H2_127300 - Right of use - cost (gross carrying amount)
# 548313061.77
# H2_127400 - Right of use - accumulated amortisation and impairment
# 29641240.669999998
# H2_127003 - Work In Progress
# 441415.73
# H2_127500 - Work In Progress
# 826196.52
# H2_127004 - Biodiversity credits
# -1802657.96
# H2_127600 - Gross carrying value (at fair value)
# 0.58
# H2_128000 - Other assets
# 136277.28
# H2_128002 - Prepaid asset
# 208867.52
# H2_128400 - Prepaid asset - light rail
# 1561915.0099999998
# H2_128500 - Prepaid asset - Sydney Metro Northwest
# -9020.05
# H2_128003 - Right to receive inventory
# -123446.71
# H2_128300 - Right to receive assets
# 1043726.72
# H2_128310 - Right to receive - plant and equipment
# -10593.75
# H2_128320 - Right to receive - intangibles
# 4153.84
# H2_128360 - Right to receive - accumulated amortisation and impairment
# 1511669598.03
# H2_128330 - Right to receive - leasehold improvements
# 1511669598.03
# H2_128340 - Right to receive - inventory (including fuel)
# 42518856.37
# H2_125800 - Right-of-use assets
# None
# H2_125811 - Land- Right of Use Asset
# 0
# H2_125810 - Land- Right of Use Asset
# -966861.48
# H2_125815 - Accumulated depreciation - Land- Right of Use Asset
# 1000000
# H2_125812 - Buildings and improvements- Right of Use Asset
# 227996621.23
# H2_125820 - Buildings and improvements- Right of Use Asset
# 320634595.06
# H2_125825 - Accumulated depreciation- Buildings and improvements - ROU
# 8007601.49
# H2_125813 - Plant and equipment- Right of Use Asset
# 180209947.56
# H2_125830 - Plant and equipment- Right of Use Asset
# 129425480.42999999
# H2_125835 - Accumulated depreciation- Plant and equipment - Right of Use
# 11935604.049999999
# H2_125814 - Buses - Right of Use Asset
# 83730.75
# H2_125831 - Buses - Right of Use Asset
# 83730.75
# H2_125836 - Accumulated Depreciation- Buses - Right of Use Asset
# 267000
# H2_125816 - Rolling stock – Right of use Asset
# 1982455.45
# H2_125840 - Rolling stock – Right of use Asset
# 386705355.96
# H2_125845 - Accumulated depreciation- Rolling tock - ROU
# 180725.41
# H2_125817 - Infrastructure- Right of Use Asset
# 238640749.22
# H2_125850 - Infrastructure- Right of Use Asset
# -2363335.2199999997
# H2_125855 - Accumulated depreciation- Infrastructure - ROU
# -24286.5
# H2_125818 - Ferries - Right of Use Asset
# -22701.82
# H2_125805 - Right of use adjustments
# 11029608
# H2_300000 - Total liabilities
# 3486894
# H2_310000 - Total current liabilities
# 2187622
# H2_311000 - Payables
# 1184931.3
# H2_311001 - Trade creditors
# 5384300
# H2_311200 - Trade creditors
# -14269790
# H2_311011 - Inter entity payables
# -26666872
# H2_311002 - Accrued expenses
# 7219301
# H2_311100 - Accrued salaries, wages and on-costs
# 4368349
# H2_311400 - Other accruals
# 139179.93
# H2_311003 - Other creditors
# 3383
# H2_311500 - Other creditors
# 327
# H2_311004 - Personnel services payable
# 87938871.48
# H2_311700 - Personnel services payable
# 2940345504.41
# H2_311005 - Creditors arising from compulsory acquisitions
# 639287853.17
# H2_315750 - Contract liabilities
# 10117879.51
# H2_312000 - Borrowings
# 1592224748.82
# H2_312400 - Other loans and deposits
# 1592224748.83
# H2_312500 - Lease liabilities- Right of Use Asset
# 0
# H2_312600 - Service concession financial liabilities
# 6500000
# H2_313000 - Employee benefits
# 16067570505.48
# H2_313100 - Annual leave
# 0
# H2_313200 - Long service leave
# 6253014388.74
# H2_313300 - Workers compensation insurance
# 448765843.9
# H2_313400 - Payroll tax
# 3250
# H2_313500 - Fringe benefits tax
# 69432595.06
# H2_313600 - Public holidays
# 10500569.9
# H2_313700 - Superannuation
# 97491538.01
# H2_313800 - Severance payments / redundancies
# 9797168.09
# H2_314000 - Other provisions
# 3428
# H2_314150 - Ballast disposal
# 3233135.8600000003
# H2_314200 - Land and buildings remediation
# 109504.75
# H2_314250 - Lease make good costs
# 29507758
# H2_314300 - Legal and related claims
# 609222
# H2_314350 - Property reimbursement claims
# 241654
# H2_314500 - Public liability claims
# 1496322
# H2_314650 - Other
# 3399780
# H2_314610 - Integrated Station Development payment obligations
# 3493936.89
# H2_317000 - Derivative liabilities
# 16594957.39
# H2_316110 - Foreign exchange derivatives - cash flow hedges
# 16594957.39
# H2_316120 - Energy derivative - cash flow hedges
# 5563935.94
# H2_315000 - Other liabilities
# 113032680.43
# H2_315200 - Statutory creditors
# 162189
# H2_315400 - Holding accounts
# 10233585
# H2_315350 - Miscellaneous holding account
# 20087150.32
# H2_315351 - Opal card holding accounts
# 16375
# H2_315410 - Other holding accounts
# 1311661.92
# H2_315420 - E-tag holding accounts
# 221039314.02999997
# H2_315450 - Grant of right to operate liability under service concession
# 592656695.27
# H2_315500 - Lease incentive
# 627676933.9
# H2_315600 - Deferred revenue
# 627676933.9
# H2_315800 - Liability for former employees leave entitlements
# 3453027.26
# H2_315900 - Other
# None
# H2_315960 - Liabilities to construct non-financial assets
# 188216.64
# H2_320000 - Total non-current liabilities
# None
# H2_321500 - Payables
# 322536722.59
# H2_321520 - Accruals
# 303955617.18
# H2_324650 - Contract liabilities
# 18581105.41
# H2_321000 - Borrowings
# -81739143.29
# H2_321400 - Other loans and deposits
# -83385421.94
# H2_321600 - Lease liabilities- Right of Use Asset (non-current)
# -1443386.4500000002
# H2_321700 - Service concession financial liabilities
# 21454790.54
# H2_322000 - Employee benefits
# 463353.51
# H2_322200 - Long service leave
# 140679.83
# H2_322300 - Severance payments/redundancies
# 627201.42
# H2_322500 - Workers compensation insurance
# 2.52
# H2_322600 - Superannuation
# 2.52
# H2_322620 - Superannuation Provision DBS
# 5.04
# H2_323000 - Other provisions
# 30937915.18
# H2_323300 - Land and buildings remediation
# 10591981.08
# H2_323400 - Lease make good costs
# 3453027.2600000002
# H2_323830 - Biodiversity credits
# 79874760.99
# H2_323900 - Other
# 31658410.33
# H2_325100 - Derivative liabilities
# 6475969.18
# H2_325110 - Foreign exchange derivatives - cash flow hedges
# 5375207.6
# H2_324000 - Other liabilities
# 47520759.76
# H2_324200 - Deferred revenue
# 188216.64
# H2_324500 - Other
# 779361.68
# H2_324600 - Security deposit
# -101460.12
# H2_324700 - Lease incentives
# 29546.24
# H2_324150 - Grant of right to operate liability under service concession
# 540150
# H2_390000 - Other clearing and technical accounts
# 2618.3
# H2_399000 - Zero balance splitting accounts
# 1552609.86
# H2_SCI - Total Comprehensive Income
# 69090744.73
# H2_NR - Net result
# 11647788.110000001
# H2_OR - Operating result
# 2722565.31
# H2_400000 - Total revenue
# 168985.25
# H2_401000 - Appropriation
# 740591.85
# H2_410000 - Recurrent appropriations
# 5099039.760000001
# H2_411000 - Total recurrent drawdowns from NSW Treasury
# -30
# H2_425000 - Sale of goods and services
# 709654.17
# H2_425100 - Passenger service revenue
# 5382548.4
# H2_425150 - Toll revenue including E-tag
# 40604022.39
# H2_425250 - Number plates
# 23102489.15
# H2_425300 - Fees earned from maritime infrastructure assets
# 1484181.6199999999
# H2_425310 - Boat licences and registrations
# 9688756.77
# H2_425400 - Heavy Vehicles Permit Fees
# -0.04
# H2_425450 - Advertising
# 23681042.1
# H2_425500 - Publications
# 1943072.86
# H2_425550 - Fees for services rendered
# -64588.56
# H2_425551 - Fees for personnel and other services
# 13958.57
# H2_425600 - Other
# -8130000.399999999
# H2_425601 - Other
# 30935341.340000004
# H2_425700 - Major events revenue
# 2146160.69
# H2_425750 - Training
# 19034.27
# H2_425850 - Recoupment of project costs
# 147.27
# H2_430000 - Investment revenue
# 6417.51
# H2_430100 - Rental Income
# 1722.6
# H2_430300 - Interest income from financial assets at amortised cost
# 3691862.35
# H2_430600 - Ferry lease revenue
# -2965932.75
# H2_435300 - M2 and Eastern Distributor promissory notes
# 3428256.6599999997
# H2_460000 - Shared and corporate services revenue
# 1054942.99
# H2_440000 - Retained fees and fines
# 1274857.15
# H2_440200 - Fines
# 633126.58
# H2_440400 - Fees
# 12739259.319999998
# H2_445000 - Grants and contributions
# 129366.17
# H2_445100 - Community transport grants
# 132206.06
# H2_445700 - Other NSW Government agencies (non-transport)
# 10168399.21
# H2_445200 - Private firms and individuals
# 63284.89
# H2_445600 - Grants from Transport for NSW
# 4039247.5700000003
# H2_445300 - Crown Entity
# 194996.13
# H2_445500 - Other State and Territory government agencies
# 1393843.7699999998
# H2_465000 - Major rail project revenue
# 14599624.41
# H2_465100 - Major rail project revenue
# 12222103.73
# H2_450000 - Acceptance by the Crown Entity of empl. Ben. and oth. Liab.
# 2254226.85
# H2_450100 - Superannuation - defined benefit
# 2498363.42
# H2_450200 - Long service leave
# 1141997511.56
# H2_450300 - Payroll tax
# 31819647.38
# H2_455000 - Personnel services revenue
# 329672726.37
# H2_455100 - Fee for personnel services
# 5117026.14
# H2_435000 - Other income
# -87005290.22
# H2_435252 - Revenue related to service concession arrangements
# 3950520.28
# H2_435600 - Other
# 48606.85
# H2_500000 - Total expenses excluding losses
# 6073.57
# H2_510000 - Operating expenses
# 67468263.59
# H2_511000 - Employee-related expenses
# -2263725.78
# H2_511100 - Salaries and wages (including annual leave)
# 893105.98
# H2_511200 - Superannuation - defined benefit plans
# 2999.82
# H2_511300 - Superannuation - defined contribution plans
# 9185.06
# H2_511400 - Long service leave
# None
# H2_511500 - Workers compensation insurance
# None
# H2_511600 - Payroll tax and fringe benefit tax
# None
# H2_511700 - Redundancy payments
# None
# H2_511800 - Other employee expenses
# None
# H2_507100 - Employee-related expenses allocated to capital expenditure
# 168948588.9
# H2_507200 - Employee-related expenses allocated to captial construction
# 28095041.099999998
# H2_512000 - Personnel services expenses
# 80552299.2
# H2_512040 - Salaries and wages (including annual leave)
# 115287305.46000001
# H2_512050 - Superannuation - defined benefit plans
# 95221633.15
# H2_512060 - Superannuation - defined contribution plans
# 93807325.21000001
# H2_512010 - Long service leave
# 53916498.17
# H2_512070 - Workers compensation insurance
# 4147975.75
# H2_512020 - Payroll tax and fringe benefits tax
# 18268315.06
# H2_512030 - Redundancy payments
# 1054024.98
# H2_512080 - Other personnel services expenses
# 22716819.52
# H2_509000 - Personnel exp allocated to capital expenditure
# 78751387.01
# H2_509100 - Personnel exp allocated to capital construction
# 464549.94
# H2_513000 - Other operating expenses
# -141141.2
# H2_513007 - Auditor's remuneration - audit of financial statements
# 6745335.8
# H2_513008 - Advertising and marketing
# 2443088.36
# H2_513010 - Cashback refund - M4/M5
# 826348715.0799999
# H2_513011 - Communications
# 20855395.099999998
# H2_513002 - Electricity, gas and water
# 2617204.05
# H2_513005 - Fleet and equipment hire and leasing charges
# 1740175344
# H2_513013 - Fuel costs
# 2610122039
# H2_513014 - General expenses
# 10529973.02
# H2_513015 - Information technology
# 48800739.129999995
# H2_513004 - Insurance
# 9259092.92
# H2_513016 - Internal audit fees
# 183860.02
# H2_513017 - Land and buildings remediation
# -9905078.53
# H2_513018 - Legal services
# -0.01
# H2_510001 - Other operating expenses
# 4589451.8
# H2_510510 - Cost of Inventory held for distribution
# 905.85
# H2_521010 - Plant and equipment
# -905.85
# H2_530210 - Service costs from Rail entities
# -2638492.67
# H2_541101 - Inter agency support services
# 531050.31
# H2_541401 - Other
# 2437178.29
# H2_513029 - Maintenance
# 1278478.2300000002
# H2_514100 - Maintenance  - general
# None
# H2_514200 - Maintenance  - buses and ferries
# None
# H2_514300 - Maintenance  - rail infrastructure system
# None
# H2_514400 - Maintenance  - trains
# None
# H2_514500 - Maintenance  - road and maritime infrastructure system
# None
# H2_513019 - Materials
# None
# H2_513021 - Office expenses
# None
# H2_513022 - Consultants and other contractors
# None
# H2_513023 - Payments to councils and external bodies
# None
# H2_513003 - Property charges
# None
# H2_513024 - Security costs
# None
# H2_513006 - Taxes, rates and related charges
# None
# H2_513001 - Travel expenses
# None
# H2_513031 - Special number plates concession fees
# None
# H2_513035 - Share service charges
# None
# H2_513036 - Expenses relating to short term leases
# None
# H2_513038 - Variable lease payments not included in lease liabilities
# None
# H2_513039 - Access fees
# None
# H2_560000 - Major rail project expenses
# None
# H2_561000 - Personnel-related expenses
# None
# H2_562000 - Skill hire contractors
# None
# H2_563000 - Professional service contractors
# None
# H2_564000 - Property acquisition
# None
# H2_565000 - Insurance
# None
# H2_566000 - Legal services
# None
# H2_567000 - Rent and other related expenses
# None
# H2_568000 - Information technology and telecommunication expenses
# None
# H2_569000 - Consultants
# None
# H2_569500 - Other
# None
# H2_520000 - Depreciation and amortisation
# None
# H2_520100 - Depreciation - property, plant and equipment
# None
# H2_520101 - Depreciation - road and maritime infrastructure systems
# None
# H2_520104 - Depreciation - rail infrastructure systems
# None
# H2_520102 - Depreciation - buildings
# None
# H2_520105 - Depreciation - rolling stock
# None
# H2_520106 - Depreciation - ferries
# None
# H2_520107 - Depreciation - buses
# None
# H2_520103 - Depreciation - plant and equipment
# None
# H2_520200 - Amortisation
# None
# H2_520210 - Intangible assets
# None
# H2_520110 - Depreciation- right-of-use assets
# None
# H2_520111 - Depreciation for land and buildings
# None
# H2_520112 - Depreciation for plant and equipment
# None
# H2_530000 - Grants and subsidies
# None
# H2_530200 - Taxi Transport Subsidy Scheme
# None
# H2_530100 - Community transport groups
# None
# H2_530300 - Private Vehicle Conveyance
# None
# H2_530400 - Carparks and interchanges
# None
# H2_530600 - Grants to local councils - maintenance of transport infrastr
# None
# H2_530755 - Grants to local councils & other parties - tfr of assets
# None
# H2_530800 - National transport regulators
# None
# H2_530900 - Road safety grant to NSW Police
# None
# H2_531000 - Others
# None
# H2_531001 - Others
# None
# H2_531200 - Rail services and capital works
# None
# H2_535000 - Ferry services and capital works
# None
# H2_531500 - Point to point assistance package
# None
# H2_531600 - Sydney Metro Grants
# None
# H2_540000 - Finance costs
# None
# H2_541000 - Finance lease interest charges
# None
# H2_545000 - Interest expense - Right of use asset
# None
# H2_544000 - Other finance costs
# None
# H2_545500 - Interest Expense Service Concession Finance Liability
# None
# H2_550000 - Other expenses
# None
# H2_551000 - Bus contract payments - metropolitan and outer metro bus op
# None
# H2_552000 - Major events - hire of bus and rail services
# None
# H2_555000 - Ferry contract payments
# None
# H2_556000 - Light rail contract payments
# None
# H2_558000 - Bus contract payments - rural and regional bus operators
# None
# H2_559000 - Nightride bus services
# None
# H2_553000 - Sydney Metro contract payments
# None
# H2_490000 - Gains/(losses) on disposal
# None
# H2_490010 - Proceeds from asset sale
# None
# H2_490020 - Net carrying amount of property, plant and equipment disposed
# None
# H2_490050 - Gains/(losses) on disposal of non - current assets held for sale
# None
# H2_490025 - Net gains/(losses) on disposal of right of use assets and lease liabilities
# None
# H2_495000 - Other gains/(losses)
# None
# H2_495400 - Bad debts (written off) /recovered
# None
# H2_495420 - Bad debts (written off)/recovered
# None
# H2_495500 - Other
# None
# H2_495530 - Realised and unrealised gains/(losses) on other financial instruments at fair value through profit or loss
# None
# H2_495550 - Foreign exchange gains/(losses)
# None
# H2_495560 - Realised and unrealised gains/(losses) on derivatives
# None
# H2_494000 - Impairment reversal/(losses) on financial assets
# None

# %%
#**************************************************************************************This is a version that retains the formulas**************************************************************************
from numpy.core.multiarray import concatenate
import pandas as pd
import openpyxl
import numpy as np
import re
from openpyxl.styles import PatternFill, Border, Side, Alignment, Protection, Font

wb = openpyxl.load_workbook('/content/DoT (Cluster) AR.xlsx', data_only=False, rich_text=True)
indx_sheet = wb['Index']
add_col_idx = indx_sheet.max_column + 1
#sheet_names = wb.sheetnames
# Use the following SWITCH to define "scope" of the script. False = Do not apply, True = Apply
Font_Size_Switch = True
Row_Height_Switch = True
Border_Switch = True # False will not remove vertical borders
Column_Width_Switch = True
#print(wb.sheetnames)#
for title in wb.sheetnames:
  print("Start of", title)
  ws = wb[title]
#  hidden_flg = ws.sheet_state
  for name_range in wb.defined_names.values():
   char_idx = name_range.attr_text.find('!')
   #print(ws.sheet_state)
   if ws.title==name_range.attr_text[:char_idx] and ws.sheet_state == 'visible':
    #named_array = wb.defined_names[title]
    #print("I am processing",ws.title)
    cell_range=name_range.attr_text
    #print(cell_range)
    start_cell, end_cell = cell_range.split(':')
    sheet, start_cell = start_cell.split('!')
    start_cell = start_cell.replace("$","")
    end_cell = end_cell.replace("$","")
    start_row, start_col = openpyxl.utils.cell.coordinate_to_tuple(start_cell)
    end_row, end_col= openpyxl.utils.cell.coordinate_to_tuple(end_cell)
    row_height = 14.5
    index = 0
    num_count = 0
    cnt_nts = 0
    hidden_columns = []
    notes_exists = False
    min=0
    max=0
    h_min=0
    h_max=0
    true_end = end_col
    hiddenList=[]
    groupedList=[]

    #Thi block loops on rows defined in the named range to find Notes colum
    for row in ws.iter_rows():
        for row_cell in row:
         if row_cell.value =="Notes" or row_cell.value =="Note":
          notes_exists=True
          cnt_nts = row_cell.col_idx
          print("Notes Index position",cnt_nts)
          break
    # This block determines number of numeric columns

    for col_h in range(start_col , end_col + 1):
        sheet_cell = ws.cell(row=end_row, column=col_h)
        #print("sheet scope", sheet_cell.value, col_h, bool )
        #print(col_h, ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min, ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max, ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].hidden, ws.title )
        if col_h in groupedList: #col_h == true_end and not ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min:
          ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min = col_h
          ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max = col_h
          num_count += 1
          print("I am columns", col_h,"I am in condition 0")
          continue
        if col_h in hiddenList: #min and max and col_h > min and col_h <= max and not ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].hidden :
             print("I am column", col_h, "and I am in condition 1")
             continue
        elif not ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].hidden and ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min == ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max: #This is a default scenario for visible columns
             #print(type(sheet_cell.value))
             if (re.match(r'^#',last_row_values.number_format)) and col_h != cnt_nts: # isinstance(sheet_cell.value, (int, float)): #
                  num_count += 1
                  print("I am column", col_h, "and I am in condition 2")
        elif ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].hidden and ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min != ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max:   #This capture the first cell of hidden cell range
              hiddenList.clear()
              for i in range(ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min, ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max + 1):
                            hiddenList.append(i)
              h_min = ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min
              h_max = ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max
              print("I am column", col_h, "and I am in condition 3", hiddenList )
              continue
        elif not ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].hidden and ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min != ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max:   #This captures any grouped columns that have min & max defined None and are visible in excel
              groupedList.clear()
              for i in range(ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min, ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max + 1):
                            groupedList.append(i)
              min = ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min
              max = ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].max
              num_count += 1
              print("I am column", col_h, "and I am in condition 4",min,max, groupedList)

    print("Numeric columns", num_count, ws.title)


    #Loop on rows defined in the named range
    for row in range(start_row, end_row + 1):
      index += 1
      if Row_Height_Switch is True:
        #set the row height to 14.5
        ws.row_dimensions[row].height=row_height
        Is_hidden = ws.row_dimensions[row].hidden
      groupedList.clear()
      hiddenList.clear()
      col_index=start_col + 1
# Loop on columns starting from the range defined in Named Range
      for col in range(start_col , end_col + 1):
       sheet_cell = ws.cell(row=row, column=col)
       if index==1: #Row 1
        last_row_values = ws.cell(row=end_row, column=col)
#******This block is to hide columns that come as visible due to excel functionality to Group columns that are hidden consecutively hidden********
        if col in groupedList: #col_h == true_end and not ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].min:
          fstyle_bold = sheet_cell.font.bold
          fstyle_italic = sheet_cell.font.italic
        if col_h in hiddenList: #min and max and col_h > min and col_h <= max and not ws.column_dimensions[openpyxl.utils.get_column_letter(col_h)].hidden :
          ws.column_dimensions[openpyxl.utils.get_column_letter(col)].hidden = True
          continue
        elif not ws.column_dimensions[openpyxl.utils.get_column_letter(col)].hidden and ws.column_dimensions[openpyxl.utils.get_column_letter(col)].min == ws.column_dimensions[openpyxl.utils.get_column_letter(col)].max: #This is a default scenario for visible columns
          fstyle_bold = sheet_cell.font.bold
          fstyle_italic = sheet_cell.font.italic
        elif ws.column_dimensions[openpyxl.utils.get_column_letter(col)].hidden and ws.column_dimensions[openpyxl.utils.get_column_letter(col)].min != ws.column_dimensions[openpyxl.utils.get_column_letter(col)].max:   #This capture the first cell of hidden cell range
          hiddenList.clear()
          for i in range(ws.column_dimensions[openpyxl.utils.get_column_letter(col)].min, ws.column_dimensions[openpyxl.utils.get_column_letter(col)].max + 1):
                            hiddenList.append(i)
          print("I am column", col_h, "and I am in condition 3", hiddenList )
          continue
        elif not ws.column_dimensions[openpyxl.utils.get_column_letter(col)].hidden and ws.column_dimensions[openpyxl.utils.get_column_letter(col)].min != ws.column_dimensions[openpyxl.utils.get_column_letter(col)].max:   #This captures any grouped columns that have min & max defined None and are visible in excel
          groupedList.clear()
          for i in range(ws.column_dimensions[openpyxl.utils.get_column_letter(col)].min, ws.column_dimensions[openpyxl.utils.get_column_letter(col)].max + 1):
                            groupedList.append(i)
          fstyle_bold = sheet_cell.font.bold
          fstyle_italic = sheet_cell.font.italic
          print("I am column", col_h, "and I am in condition 4",min,max, groupedList)
#********End of block*************

        if not Font_Size_Switch:
            font_size = sheet_cell.font.size
        else:
            # Set the font SIZE based on numeric columns
            if num_count <= 8:
              font_size = 9
            elif num_count in (9, 10):
              font_size = 8
            else:
              font_size = 7

 #******This block sets the Column Width at row of the defined range as this block is executed within Index 1 if condition above
        if Column_Width_Switch is True:
          if notes_exists and col==col_index:
              if num_count == 1:
                   col_width = 8.91
              elif num_count == 2:
                   col_width = 8.91
              elif num_count==3:
                   col_width = 8.91
              elif num_count==4:
                   col_width=8.18
              elif num_count==5:
                   col_width=7.82
              elif num_count==6:
                   col_width=8.91
              elif num_count==7:
                   col_width=8.55
              elif num_count==8:
                   col_width=8.18
              elif num_count==9:
                   col_width=7.82
              elif num_count==10:
                   col_width=7
              elif num_count==11:
                   col_width=6.18
              else:
                   col_width=6.18
              print("I am using", col_width, "for Notes columns in sheet", ws.title)
                # now update the worksheet with above column widths
              ws.column_dimensions[openpyxl.utils.get_column_letter(col)].width=col_width
          if col==start_col and not notes_exists: #This is for column 1
                #Set the default column WIDTH of first colum based on how many numeric columns
                if num_count == 1:
                    col_width = 65.55 + 8.91
                elif num_count == 2:
                    col_width = 53.55 + 8.91
                elif num_count==3:
                    col_width = 41.45 + 8.91
                elif num_count==4:
                    col_width=34.18 + 8.18
                elif num_count==5:
                    col_width=26.09 + 7.82
                elif num_count==6:
                    col_width=49 + 8.91
                elif num_count==7:
                    col_width=40.82 + 8.55
                elif num_count==8:
                    col_width=33.64 + 8.18
                elif num_count==9:
                    col_width=27.55 + 7.82
                elif num_count==10:
                    col_width=27.91 + 7
                elif num_count==11:
                    col_width=61.4 + 6.18
                else:
                    col_width=21.64 + 6.18
                ws.column_dimensions[openpyxl.utils.get_column_letter(col)].width=col_width
                # set the column widths in worksheet
                print(col, col_width, "for label")
          if col==start_col and notes_exists: #This is for column 1
                #Set the default column WIDTH of first colum based on how many numeric columns
                if num_count == 1:
                    col_width = 65.55
                elif num_count == 2:
                    col_width = 53.55
                elif num_count==3:
                    col_width = 41.45
                elif num_count==4:
                    col_width=34.18
                elif num_count==5:
                    col_width=26.09
                elif num_count==6:
                    col_width=49
                elif num_count==7:
                    col_width=40.82
                elif num_count==8:
                    col_width=33.64
                elif num_count==9:
                    col_width=27.55
                elif num_count==10:
                    col_width=27.91
                elif num_count==11:
                    col_width=61.4
                else:
                    col_width=21.64
                # set the column widths in worksheet
                print(col, col_width, "for label")
                ws.column_dimensions[openpyxl.utils.get_column_letter(col)].width=col_width
                print(ws.column_dimensions[openpyxl.utils.get_column_letter(col)].width)
          if (re.match(r'^#',last_row_values.number_format)) and col!=cnt_nts: #isinstance(last_row_values, (int, float)): #
                #Set the default column WIDTH for numeric column based on how many amount columns are in sheet
                if num_count <= 3 or num_count==6:
                   col_width = 11.45
                elif num_count == 4:
                   col_width = 10.36
                elif num_count==5:
                   col_width = 9.91
                elif num_count==7:
                   col_width=10.91
                elif num_count==8:
                   col_width=10.36
                elif num_count==9:
                   col_width=9.64
                elif num_count==10:
                   col_width=8.82
                else:
                   col_width=7.91
                print("I am using", col_width, "for amount")
                # set the column widths in worksheet
                ws.column_dimensions[openpyxl.utils.get_column_letter(col)].width=col_width
        elif not Column_Width_Switch:
          ws.column_dimensions[openpyxl.utils.get_column_letter(col)].width=ws.column_dimensions[openpyxl.utils.get_column_letter(col)].width
#********This block sets the font size and formatting properties of cell***************
       font_prpts = {}
       if Font_Size_Switch and index == 1:
         #set the font properties for row 1
         fstyle_bold = sheet_cell.font.bold
         fstyle_italic = sheet_cell.font.italic
         fstyle_size = sheet_cell.font.size
         #print("I am setting", fstyle_bold, "font properties of", row, col)
         font_prpts= { "name": "Arial",
              "size": fstyle_size,
              "bold": fstyle_bold,
              "italic": fstyle_italic,
              "vertAlign":"baseline",
              "underline":"none",
              "strike":False }
         font = Font(**font_prpts)
         sheet_cell.font = font
       elif Font_Size_Switch and index != 1:
         fstyle_bold = sheet_cell.font.bold
         fstyle_italic = sheet_cell.font.italic
         fstyle_size = sheet_cell.font.size
         #print("I am setting", fstyle_bold, "font properties of", row, col)
        #set the font properties for remaining rows
         font_prpts= { "name": "Arial",
              "size": fstyle_size if not Font_Size_Switch else 9.0,
              "bold": fstyle_bold,
              "italic": fstyle_italic,
              "vertAlign":"baseline",
              "underline":"none",
              "strike":False }
       font = Font(**font_prpts)
       sheet_cell.font = font
#*********This block sets the formatting properties*****************#
       if Border_Switch == True and not 'PPE' in ws.title:
          if sheet_cell.border.left.border_style == "thin" or sheet_cell.border.right.border_style == "thin":
             sheet_cell.border.left.border_style = 'none'
             sheet_cell.border.right.border_style = 'none'
             print("a border is removed at cell location", col, ws.title)
       if row == start_row and sheet_cell.value=="Notes" or sheet_cell.value=="Note":
             sheet_cell.alignment = Alignment(horizontal='right',
                                              vertical = 'bottom',
                                              wrap_text=True)
       elif row == start_row and sheet_cell.value!="Notes" or sheet_cell.value=="Note":
               sheet_cell.alignment = Alignment(horizontal='right',
                                                vertical = 'bottom',
                                                wrap_text=True)
       elif row != start_row and col == start_col:
             cell_index = sheet_cell.alignment.indent
             sheet_cell.alignment = Alignment(horizontal='left',
                                                vertical = 'bottom',
                                                wrap_text=True,
                                                indent=cell_index)
       elif col==col_index and notes_exists:
               sheet_cell.alignment = Alignment(horizontal='right',
                                                vertical = 'bottom',
                                                wrap_text=True)
               sheet_cell.number_format = 'General'

       else:
               sheet_cell.alignment = Alignment(horizontal='right',
                                                vertical = 'bottom',
                                                wrap_text=False)

  for irow in indx_sheet.iter_rows(min_row=2, max_row=indx_sheet.max_row, min_col=1, max_col=indx_sheet.max_column):
    for icell in irow:
      if icell.value==ws.title:
        indx_sheet.cell(row=icell.row, column=add_col_idx, value=num_count)

wb.save('test.xlsx')
